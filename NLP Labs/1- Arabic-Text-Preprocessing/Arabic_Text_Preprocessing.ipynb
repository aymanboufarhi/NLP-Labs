# %% [markdown]
# <a href="https://colab.research.google.com/github/aymanboufarhi/Arabic-Text-Preprocessing/blob/main/Arabic_Text_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab** : Get familiar with Scraping and NLP Pipeline ( Arabic Text )

# %% [markdown]
# Import Libraries :

# %%
import requests
from bs4 import BeautifulSoup
import json
import pymongo
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.stem.isri import ISRIStemmer
from nltk.stem.arlstem import ARLSTem
from nltk import ne_chunk
from ar_corrector.corrector import Corrector

# %% [markdown]
# # **Data Acquisition**

# %% [markdown]
# Extracting raw content from the website mawdoo3 :

# %%
url='https://mawdoo3.com/%D8%AB%D9%82%D8%A7%D9%81%D8%A9_%D8%B9%D8%A7%D9%85%D8%A9_%D8%AD%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%BA%D8%B1%D8%A8'
req=requests.get(url)
content=req.text

# %% [markdown]
# Parse the raw content into a readable format :

# %%
soup=BeautifulSoup(content, "html.parser")

# %% [markdown]
# Connection to MongoDB Atlas :

# %%
# Define the MongoDB Atlas connection string
connection_string = ""

# Connect to MongoDB Atlas
client = pymongo.MongoClient(connection_string)

# Access the database and collection
db = client["web_scraping_db"]
collection = db["web_data_collection"]

# %% [markdown]
# Store the raw data into a MongoDB collection :

# %%
# Store the entire HTML content
data_to_store = {
    "url": url,
    "html_content": str(soup)
}

# Insert the data into MongoDB
insert_result = collection.insert_one(data_to_store)
print("Data inserted with ID:", insert_result.inserted_id)
# Out:
# Data inserted with ID: 66113baac154ef6dd4e56c11

# %% [markdown]
# Retrieve data from MongoDB :

# %%
collection = db["web_data_collection"]

data_from_db = collection.find_one()

# Extract HTML content from data
html_content = data_from_db["html_content"]

# Parsing HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Extract text from HTML
text = soup.get_text()

# %% [markdown]
# # **Text Cleaning**

# %% [markdown]
# Function to clean the raw data :

# %%
def clean_text(txt):
    # Remove HTML tags and non-Arabic characters
    clean = re.sub('<[^<]+?>', '', txt)
    # Define regex pattern to match Arabic alphabet and spaces
    pattern = re.compile(r'[^\u0600-\u06FF\s]+')
    # Substitute non-matching characters with an empty string
    clean = re.sub(pattern, '', clean)
    # Remove extra spaces
    clean = re.sub(r'\s+', ' ', clean)
    return clean

def extract_and_clean_text(soup):
    # Find all h1 and p tags
    tags = soup.find_all(['h1', 'p'])
    # Extract text from tags
    extracted_text = ''
    for tag in tags:
        extracted_text += tag.get_text() + '\n'
    # Clean extracted text
    cleaned_text = clean_text(extracted_text)
    return cleaned_text


# Print the cleaned text
cleaned_text = extract_and_clean_text(soup)

cleaned_text
# Out:
# 'ثقافة عامة حول المغرب تمت الكتابة بواسطة محمد مروان آخر تحديث ١٨٣١ ، ٣ فبراير ٢٠٢١ تقع المغرب في شمال قارة أفريقي، ويتحدّد موقعها جغرافياً بإحداثيات درجة شمالاً و درجات غرباً، إذ إنّ لها سواحل على المحيط الأطلسي والبحر الأبيض المتوسط الذي يفصل بينهما مضيق جبل طارق، كما تحدُّها من الجانب الشرقي دولة الجزائر، ومن الجانب الجنوبيّ الجمهورية الموريتانية، ويُشار إلى أنّ مساحة المغرب الإجمالية تبلغ حوالي كم١٢ تُعدّ مدينة الرباط عاصمة المغرب، ويُقيم فيها حوالي نسمة، وفقاً لإحصائيات شهر تموز من عام م، حيث يتوزّعون على مساحة تبلغ كم، إذ تبلغ الكثافة السكانية فيها نحو شخص لكلّ كيلومتر مربع، ويُطلق على مدينة الرباط عدّة ألقاب، مثل واشنطن شمال أفريقيا؛ لأنّ شوارعها واسعة ومعالمها الأثرية مميزة، بالإضافة إلى مبانيها الحكومية والمنازل التي تمّ تحويلها إلى فنادق، وتُسمّى أيضاً بمدينة الزهور لاحتوائها على حدائق شاسعة وجميلة، كما تُلقّب الرباط بالمدينة البيضاء نظراً إلى بيئتها الهادئة٣ اعتمدت المغرب العلم الوطنيّ رسمياً في السابع عشر من شهر تشرين الثاني لعام م، حيث كان قبل ذلك رايةً باللون الأحمر فقط دون أيّة علامات أخرى، وصمّم العلم المغربيّ السلطان يوسف الذي حكم البلاد بين عاميّ م، حيث يتألّف العلم من مستطيل باللون الأحمر تتوسطه نجمة خماسية باللون الأخضر، إذ يرمز اللون الأحمر إلى الشجاعة والقوة، فيما يُشير اللون الأخضر إلى الدين الإسلامي ويرمز للحب، والفرح، والأمل، والسلام، والحكمة، أمّا النجمة الخماسية فتُمثّل أركان الإسلام الخمسة٤ يبلغ عدد سكان المغرب بحسب إحصائيات الأمم المتحدة حتّى اليوم الثاني من شهر شباط لعام نحو نسمة، بمتوسط عمر عام، في حين تصل الكثافة السكانية فيها إلى شخص لكلّ كيلو متر مربع، حيث تحتل المغرب المرتبة عالمياً من حيث عدد السكان، ويُمثّل عددهم نسبةً تصل إلى من إجماليّ سكان العالم،٥ ويتألّف الشعب المغربيّ من عدّة فئات عرقية مختلفة، أهمّها العرب والأمازيغ وهم السُّكان الأصليون، وأقليّات من الأوروبيين المعروفين باسم المغاربة البيض، وهم مغاربة من أصل أوروبي كالإسبان والفرنسيين، بالإضافة إلى مجموعة من اليهود٦ يُعدّ نظام الحكم في دولة المغرب ملكيّاً دستوريّاً كما أقرّه الدستور الأول في عام م، وهو نظام برلمانيّ ديمقراطيّ اجتماعيّ، يُعتبر فيه الملك صاحب السلطة العليا في الدولة، والقائد الأعلى للقوات المسلحة الملكية، ويرأس المجلس الأعلى للقضاء، ويمتلك عدّة صلاحيات منها؛ تعيين رئيس الوزراء بعد إجراء الانتخابات التشريعية، وإقالة الوزراء، وحلّ مجلس النواب والحكومة، فيما يتألّف البرلمان المغربي من مجلسين تشريعيين، هما مجلس النواب الذي يضم عضواً يتمّ انتخابهم لمدّة أعوام، ومجلس المستشارين الذي يحوي عضواً على الأقل و عضواً على الأكثر، حيث يتمّ انتخابهم بشكل غير مباشر لمدّة سنوات٧ تتميز المغرب بمجموعةٍ من القطاعات الصناعيّة المتنوّعة التي كان لها دور بارز في التقليل من البطالة، ونظراً إلى خصوبة أراضيها؛ فإن القطاع الزراعيّ يُهيمن على الاقتصاد، ويُساهم بنسبة تصل إلى من الناتج المحليّ الإجماليّ ويُشغّل حوالي من الأيدي العاملة، وبسبب تأثيره الكبير على النمو الاقتصاديّ فقد أولته الحكومة المغربية اهتماماً بالغاً عن طريق مخطط المغرب الأخضر وصندوق التنمية الفلاحية٨ يُعدّ الفوسفات أيضاً مصدراً للثروة المغربية في ظلّ قلّة الموارد المعدنية، فيما يُساهم القطاع الصناعيّ فيها بنسبة تصل إلى من الناتج المحلي الإجمالي ويوظّف من القوى العاملة، ومن القطاعات الصناعية الرئيسية؛ المنسوجات، والسلع الجلدية، وتجهيز الأغذية، وتكرير النفط، بينما تشهد قطاعات جديدة ازدهاراً واضحاً؛ كالكيمياء، والسيارات، والإلكترونيات، وقطاع الطيران، أمّا قطاع الخدمات فيُمثّل نصف الناتج المحلي الإجمالي ويوفّر فرص عمل بنسبة من الأيدي العاملة٨ تتميّز المغرب بطبيعةٍ خلابةٍ وفريدة، إذ إنّها تحوي الغابات، والسهول، والبساتين، وقمم جبال الأطلس، والصخور والصحاري الرملية في الجنوب، بالإضافة إلى المواقع الدينية المختلفة التي يُمكن زيارتها، حيث إنّ المغرب تُعدّ من الدول التي ينتشر فيها التسامح والتعايش بين الأديان، ونتيجةً لذلك تتتعدّد أشكال السياحة في المغرب وتتنوّع، إذ تمتلك المغرب العديد من المواقع التاريخية والأثرية المدرجة في قائمة اليونسكو للتراث، ومنها ما يأتي٩ تتميّز معظم المناطق الواقعة في شمال الصحراء الغربية بمناخٍ حارّ صيفاً ومعتدل شتاءً، ويستمر موسم الأمطار من شهر تشرين الأول حتّى شهر نيسان، حيث يتركّز هطول الأمطار في شمال البلاد، وينخفض تدريجياً حتّى الجنوب، كما يؤدّي تيار الكناري الذي يمرّ قبالة الشواطئ المغربية إلى استقرار الحالة الجوية٢١٠ تُعتبر المغرب موطناً الأمازيغ منذ ما  ...

# %% [markdown]
# ---
#
#
# Correct word spelling using the context ( in our case we don't need it, because we extract the text from a professional website ) :

# %%
corr = Corrector()

correct_text = corr.contextual_correct(cleaned_text)

# %% [markdown]
# # **Text Preprocessing**

# %% [markdown]
# ## Unicode Normalization

# %%
normalized_text = cleaned_text.encode('UTF-16')

# %% [markdown]
# ## Tokenization

# %%
nltk.download('punkt')

# %%
normalized_text_str = normalized_text.decode('utf-16')
tokens = word_tokenize(normalized_text_str)
print("Tokens:", tokens)
# Out:
# Tokens: ['ثقافة', 'عامة', 'حول', 'المغرب', 'تمت', 'الكتابة', 'بواسطة', 'محمد', 'مروان', 'آخر', 'تحديث', '١٨٣١', '،', '٣', 'فبراير', '٢٠٢١', 'تقع', 'المغرب', 'في', 'شمال', 'قارة', 'أفريقي،', 'ويتحدّد', 'موقعها', 'جغرافياً', 'بإحداثيات', 'درجة', 'شمالاً', 'و', 'درجات', 'غرباً،', 'إذ', 'إنّ', 'لها', 'سواحل', 'على', 'المحيط', 'الأطلسي', 'والبحر', 'الأبيض', 'المتوسط', 'الذي', 'يفصل', 'بينهما', 'مضيق', 'جبل', 'طارق،', 'كما', 'تحدُّها', 'من', 'الجانب', 'الشرقي', 'دولة', 'الجزائر،', 'ومن', 'الجانب', 'الجنوبيّ', 'الجمهورية', 'الموريتانية،', 'ويُشار', 'إلى', 'أنّ', 'مساحة', 'المغرب', 'الإجمالية', 'تبلغ', 'حوالي', 'كم١٢', 'تُعدّ', 'مدينة', 'الرباط', 'عاصمة', 'المغرب،', 'ويُقيم', 'فيها', 'حوالي', 'نسمة،', 'وفقاً', 'لإحصائيات', 'شهر', 'تموز', 'من', 'عام', 'م،', 'حيث', 'يتوزّعون', 'على', 'مساحة', 'تبلغ', 'كم،', 'إذ', 'تبلغ', 'الكثافة', 'السكانية', 'فيها', 'نحو', 'شخص', 'لكلّ', 'كيلومتر', 'مربع،', 'ويُطلق', 'على', 'مدينة', 'الرباط', 'عدّة', 'ألقاب،', 'مثل', 'واشنطن', 'شمال', 'أفريقيا؛', 'لأنّ', 'شوارعها', 'واسعة', 'ومعالمها', 'الأثرية', 'مميزة،', 'بالإضافة', 'إلى', 'مبانيها', 'الحكومية', 'والمنازل', 'التي', 'تمّ', 'تحويلها', 'إلى', 'فنادق،', 'وتُسمّى', 'أيضاً', 'بمدينة', 'الزهور', 'لاحتوائها', 'على', 'حدائق', 'شاسعة', 'وجميلة،', 'كما', 'تُلقّب', 'الرباط', 'بالمدينة', 'البيضاء', 'نظراً', 'إلى', 'بيئتها', 'الهادئة٣', 'اعتمدت', 'المغرب', 'العلم', 'الوطنيّ', 'رسمياً', 'في', 'السابع', 'عشر', 'من', 'شهر', 'تشرين', 'الثاني', 'لعام', 'م،', 'حيث', 'كان', 'قبل', 'ذلك', 'رايةً', 'باللون', 'الأحمر', 'فقط', 'دون', 'أيّة', 'علامات', 'أخرى،', 'وصمّم', 'العلم', 'المغربيّ', 'السلطان', 'يوسف', 'الذي', 'حكم', 'البلاد', 'بين', 'عاميّ', 'م،', 'حيث', 'يتألّف', 'العلم', 'من', 'مستطيل', 'باللون', 'الأحمر', 'تتوسطه', 'نجمة', 'خماسية', 'باللون', 'الأخضر،', 'إذ', 'يرمز', 'اللون', 'الأحمر', 'إلى', 'الشجاعة', 'والقوة،', 'فيما', 'يُشير', 'اللون', 'الأخضر', 'إلى', 'الدين', 'الإسلامي', 'ويرمز', 'للحب،', 'والفرح،', 'والأمل،', 'والسلام،', 'والحكمة،', 'أمّا', 'النجمة', 'الخماسية', 'فتُمثّل', 'أركان', 'الإسلام', 'الخمسة٤', 'يبلغ', 'عدد', 'سكان', 'المغرب', 'بحسب', 'إحصائيات', 'الأمم', 'المتحدة', 'حتّى', 'اليوم', 'الثاني', 'من', 'شهر', 'شباط', 'لعام', 'نحو', 'نسمة،', 'بمتوسط', 'عمر', 'عام،', 'في', 'حين', 'تصل', 'الكثافة', 'السكانية', 'فيها', 'إلى', 'شخص', 'لكلّ', 'كيلو', 'متر', 'مربع،', 'حيث', 'تحتل', 'المغرب', 'المرتبة', 'عالمياً', 'من', 'حيث', 'عدد', 'السكان،', 'ويُمثّل', 'عددهم', 'نسبةً', 'تصل', 'إلى', 'من', 'إجماليّ', 'سكان', 'العالم،٥', 'ويتألّف', 'الشعب', 'المغربيّ', 'من', 'عدّة', 'فئات', 'عرقية', 'مختلفة،', 'أهمّها', 'العرب', 'والأمازيغ', 'وهم', 'السُّكان', 'الأصليون،', 'وأقليّات', 'من', 'الأوروبيين', 'المعروفين', 'باسم', 'المغاربة', 'البيض،', 'وهم', 'مغاربة', 'من', 'أصل', 'أوروبي', 'كالإسبان', 'والفرنسيين،', 'بالإضافة', 'إلى', 'مجموعة', 'من', 'اليهود٦', 'يُعدّ', 'نظام', 'الحكم', 'في', 'دولة', 'المغرب', 'ملكيّاً', 'دستوريّاً', 'كما', 'أقرّه', 'الدستور', 'الأول', 'في', 'عام', 'م،', 'وهو', 'نظام', 'برلمانيّ', 'ديمقراطيّ', 'اجتماعيّ،', 'يُعتبر', 'فيه', 'الملك', 'صاحب', 'السلطة', 'العليا', 'في', 'الدولة،', 'والقائد', 'الأعلى', 'للقوات', 'المسلحة', 'الملكية،', 'ويرأس', 'المجلس', 'الأعلى', 'للقضاء،', 'ويمتلك', 'عدّة', 'صلاحيات', 'منها؛', 'تعيين', 'رئيس', 'الوزراء', 'بعد', 'إجراء', 'الانتخابات', 'التشريعية،', 'وإقالة', 'الوزراء،', 'وحلّ', 'مجلس', 'النواب', 'والحكومة،', 'فيما', 'يتألّف', 'البرلمان', 'المغربي', 'من', 'مجلسين', 'تشريعيين،', 'هما', 'مجلس', 'النواب', 'الذي', 'يضم', 'عضواً', 'يتمّ', 'انتخابهم', 'لمدّة', 'أعوام،', 'ومجلس', 'المستشارين', 'الذي', 'يحوي', 'عضواً', 'على', 'الأقل', 'و', 'عضواً', 'على', 'الأكثر،', 'حيث', 'يتمّ', 'انتخابهم', 'بشكل', 'غير', 'مباشر', 'لمدّة', 'سنوات٧', 'تتميز', 'المغرب', 'بمجموعةٍ', 'من', 'القطاعات', 'الصناعيّة', 'المتنوّعة', 'التي', 'كان', 'لها', 'دور', 'بارز', 'في', 'التقليل', 'من', 'البطالة،', 'ونظراً', 'إلى', 'خصوبة', 'أراضيها؛', 'فإن', 'القطاع', 'الزراعيّ', 'يُهيمن', 'على', 'الاقتصاد،', 'ويُساهم', 'بنسبة', 'تصل', 'إلى', 'من', 'الناتج', 'المحليّ', 'الإجماليّ', 'ويُشغّل', 'حوالي', 'من', 'الأيدي', 'العاملة،', 'وبسبب', 'تأثيره', 'الكبير', 'على ...

# %% [markdown]
# ## Stop words

# %%
nltk.download('stopwords')

# %% [markdown]
# All stop words that exist in arabic :

# %%
# Get Arabic stop words from NLTK corpus
arabic_stopwords = nltk.corpus.stopwords.words('arabic')

print(arabic_stopwords)
# Out:
# ['إذ', 'إذا', 'إذما', 'إذن', 'أف', 'أقل', 'أكثر', 'ألا', 'إلا', 'التي', 'الذي', 'الذين', 'اللاتي', 'اللائي', 'اللتان', 'اللتيا', 'اللتين', 'اللذان', 'اللذين', 'اللواتي', 'إلى', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'أم', 'أما', 'أما', 'إما', 'أن', 'إن', 'إنا', 'أنا', 'أنت', 'أنتم', 'أنتما', 'أنتن', 'إنما', 'إنه', 'أنى', 'أنى', 'آه', 'آها', 'أو', 'أولاء', 'أولئك', 'أوه', 'آي', 'أي', 'أيها', 'إي', 'أين', 'أين', 'أينما', 'إيه', 'بخ', 'بس', 'بعد', 'بعض', 'بك', 'بكم', 'بكم', 'بكما', 'بكن', 'بل', 'بلى', 'بما', 'بماذا', 'بمن', 'بنا', 'به', 'بها', 'بهم', 'بهما', 'بهن', 'بي', 'بين', 'بيد', 'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك', 'ثم', 'ثمة', 'حاشا', 'حبذا', 'حتى', 'حيث', 'حيثما', 'حين', 'خلا', 'دون', 'ذا', 'ذات', 'ذاك', 'ذان', 'ذانك', 'ذلك', 'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذو', 'ذوا', 'ذواتا', 'ذواتي', 'ذي', 'ذين', 'ذينك', 'ريث', 'سوف', 'سوى', 'شتان', 'عدا', 'عسى', 'عل', 'على', 'عليك', 'عليه', 'عما', 'عن', 'عند', 'غير', 'فإذا', 'فإن', 'فلا', 'فمن', 'في', 'فيم', 'فيما', 'فيه', 'فيها', 'قد', 'كأن', 'كأنما', 'كأي', 'كأين', 'كذا', 'كذلك', 'كل', 'كلا', 'كلاهما', 'كلتا', 'كلما', 'كليكما', 'كليهما', 'كم', 'كم', 'كما', 'كي', 'كيت', 'كيف', 'كيفما', 'لا', 'لاسيما', 'لدى', 'لست', 'لستم', 'لستما', 'لستن', 'لسن', 'لسنا', 'لعل', 'لك', 'لكم', 'لكما', 'لكن', 'لكنما', 'لكي', 'لكيلا', 'لم', 'لما', 'لن', 'لنا', 'له', 'لها', 'لهم', 'لهما', 'لهن', 'لو', 'لولا', 'لوما', 'لي', 'لئن', 'ليت', 'ليس', 'ليسا', 'ليست', 'ليستا', 'ليسوا', 'ما', 'ماذا', 'متى', 'مذ', 'مع', 'مما', 'ممن', 'من', 'منه', 'منها', 'منذ', 'مه', 'مهما', 'نحن', 'نحو', 'نعم', 'ها', 'هاتان', 'هاته', 'هاتي', 'هاتين', 'هاك', 'هاهنا', 'هذا', 'هذان', 'هذه', 'هذي', 'هذين', 'هكذا', 'هل', 'هلا', 'هم', 'هما', 'هن', 'هنا', 'هناك', 'هنالك', 'هو', 'هؤلاء', 'هي', 'هيا', 'هيت', 'هيهات', 'والذي', 'والذين', 'وإذ', 'وإذا', 'وإن', 'ولا', 'ولكن', 'ولو', 'وما', 'ومن', 'وهو', 'يا', 'أبٌ', 'أخٌ', 'حمٌ', 'فو', 'أنتِ', 'يناير', 'فبراير', 'مارس', 'أبريل', 'مايو', 'يونيو', 'يوليو', 'أغسطس', 'سبتمبر', 'أكتوبر', 'نوفمبر', 'ديسمبر', 'جانفي', 'فيفري', 'مارس', 'أفريل', 'ماي', 'جوان', 'جويلية', 'أوت', 'كانون', 'شباط', 'آذار', 'نيسان', 'أيار', 'حزيران', 'تموز', 'آب', 'أيلول', 'تشرين', 'دولار', 'دينار', 'ريال', 'درهم', 'ليرة', 'جنيه', 'قرش', 'مليم', 'فلس', 'هللة', 'سنتيم', 'يورو', 'ين', 'يوان', 'شيكل', 'واحد', 'اثنان', 'ثلاثة', 'أربعة', 'خمسة', 'ستة', 'سبعة', 'ثمانية', 'تسعة', 'عشرة', 'أحد', 'اثنا', 'اثني', 'إحدى', 'ثلاث', 'أربع', 'خمس', 'ست', 'سبع', 'ثماني', 'تسع', 'عشر', 'ثمان', 'سبت', 'أحد', 'اثنين', 'ثلاثاء', 'أربعاء', 'خميس', 'جمعة', 'أول', 'ثان', 'ثاني', 'ثالث', 'رابع', 'خامس', 'سادس', 'سابع', 'ثامن', 'تاسع', 'عاشر', 'حادي', 'أ', 'ب', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', 'ك', 'ل', 'م', 'ن', 'ه', 'و', 'ي', 'ء', 'ى', 'آ', 'ؤ', 'ئ', 'أ', 'ة', 'ألف', 'باء', 'تاء', 'ثاء', 'جيم', 'حاء', 'خاء', 'دال', 'ذال', 'راء', 'زاي', 'سين', 'شين', 'صاد', 'ضاد', 'طاء', 'ظاء', 'عين', 'غين', 'فاء', 'قاف', 'كاف', 'لام', 'ميم', 'نون', 'هاء', 'واو', 'ياء', 'همزة', 'ي', 'نا', 'ك', 'كن', 'ه', 'إياه', 'إياها', 'إياهما', 'إياهم', 'إياهن', 'إياك', 'إياكما', 'إياكم', 'إياك', 'إياكن', 'إياي', 'إيانا', 'أولالك', 'تانِ', 'تانِك', 'تِه', 'تِي', 'تَيْنِ', 'ثمّ', 'ثمّة', 'ذانِ', 'ذِه', 'ذِي', 'ذَيْنِ', 'هَؤلاء', 'هَاتانِ', 'هَاتِه', 'هَاتِي', 'هَاتَيْنِ', 'هَذا', 'هَذانِ', 'هَذِه', 'هَذِي', 'هَذَيْنِ', 'الألى', 'الألاء', 'أل', 'أنّى', 'أيّ', 'ّأيّان', 'أنّى', 'أيّ', 'ّأيّان', 'ذيت', 'كأيّ', 'كأيّن', 'بضع', 'فلان', 'وا', 'آمينَ', 'آهِ', 'آهٍ', 'آهاً', 'أُفٍّ', 'أُفٍّ', 'أفٍّ', 'أمامك', 'أمامكَ', 'أوّهْ', 'إلَيْكَ', 'إلَيْكَ', 'إليكَ', 'إليكنّ', 'إيهٍ', 'بخٍ', 'بسّ', 'بَسْ', 'بطآن', 'بَلْهَ', 'حاي', 'حَذارِ', 'حيَّ', 'حيَّ', 'دونك', 'رويدك', 'سرعان', 'شتانَ', 'شَتَّانَ', 'صهْ', 'صهٍ', 'طاق', 'طَق', 'عَدَسْ', 'كِخ', 'مكانَك', 'مكانَك', 'مكانَك', 'مكانكم', 'مكانكما', 'مكانكنّ', 'نَخْ', 'هاكَ', 'هَجْ', 'هلم', 'هيّا', 'هَيْهات', 'وا', 'واهاً', 'وراءَك', 'وُشْكَانَ', 'وَيْ', 'يفعلان', 'تفعلان', 'يفعلون', 'تفعلون', 'تفعلين', 'اتخذ', 'ألفى', 'تخذ', 'ترك', 'تعلَّم', 'جعل', 'حجا', 'حبيب', 'خال', 'حسب', ' ...

# %% [markdown]
# Filtering the tokens :

# %%
# Filter stop words from Arabic tokens
filtered_arabic_tokens = [w for w in tokens if not w in arabic_stopwords]

print(filtered_arabic_tokens)
# Out:
# ['ثقافة', 'حول', 'المغرب', 'تمت', 'الكتابة', 'بواسطة', 'محمد', 'مروان', 'آخر', 'تحديث', '١٨٣١', '،', '٣', '٢٠٢١', 'تقع', 'المغرب', 'قارة', 'أفريقي،', 'ويتحدّد', 'موقعها', 'جغرافياً', 'بإحداثيات', 'درجة', 'شمالاً', 'درجات', 'غرباً،', 'إنّ', 'سواحل', 'المحيط', 'الأطلسي', 'والبحر', 'الأبيض', 'المتوسط', 'يفصل', 'بينهما', 'مضيق', 'جبل', 'طارق،', 'تحدُّها', 'الجانب', 'الشرقي', 'دولة', 'الجزائر،', 'الجانب', 'الجنوبيّ', 'الجمهورية', 'الموريتانية،', 'ويُشار', 'أنّ', 'مساحة', 'المغرب', 'الإجمالية', 'تبلغ', 'حوالي', 'كم١٢', 'تُعدّ', 'مدينة', 'الرباط', 'عاصمة', 'المغرب،', 'ويُقيم', 'حوالي', 'نسمة،', 'وفقاً', 'لإحصائيات', 'شهر', 'عام', 'م،', 'يتوزّعون', 'مساحة', 'تبلغ', 'كم،', 'تبلغ', 'الكثافة', 'السكانية', 'شخص', 'لكلّ', 'كيلومتر', 'مربع،', 'ويُطلق', 'مدينة', 'الرباط', 'عدّة', 'ألقاب،', 'واشنطن', 'أفريقيا؛', 'لأنّ', 'شوارعها', 'واسعة', 'ومعالمها', 'الأثرية', 'مميزة،', 'بالإضافة', 'مبانيها', 'الحكومية', 'والمنازل', 'تمّ', 'تحويلها', 'فنادق،', 'وتُسمّى', 'أيضاً', 'بمدينة', 'الزهور', 'لاحتوائها', 'حدائق', 'شاسعة', 'وجميلة،', 'تُلقّب', 'الرباط', 'بالمدينة', 'البيضاء', 'نظراً', 'بيئتها', 'الهادئة٣', 'اعتمدت', 'المغرب', 'العلم', 'الوطنيّ', 'رسمياً', 'السابع', 'شهر', 'الثاني', 'لعام', 'م،', 'رايةً', 'باللون', 'الأحمر', 'فقط', 'أيّة', 'علامات', 'أخرى،', 'وصمّم', 'العلم', 'المغربيّ', 'السلطان', 'يوسف', 'حكم', 'البلاد', 'عاميّ', 'م،', 'يتألّف', 'العلم', 'مستطيل', 'باللون', 'الأحمر', 'تتوسطه', 'نجمة', 'خماسية', 'باللون', 'الأخضر،', 'يرمز', 'اللون', 'الأحمر', 'الشجاعة', 'والقوة،', 'يُشير', 'اللون', 'الأخضر', 'الدين', 'الإسلامي', 'ويرمز', 'للحب،', 'والفرح،', 'والأمل،', 'والسلام،', 'والحكمة،', 'النجمة', 'الخماسية', 'فتُمثّل', 'أركان', 'الإسلام', 'الخمسة٤', 'يبلغ', 'عدد', 'سكان', 'المغرب', 'بحسب', 'إحصائيات', 'الأمم', 'المتحدة', 'حتّى', 'اليوم', 'الثاني', 'شهر', 'لعام', 'نسمة،', 'بمتوسط', 'عمر', 'عام،', 'تصل', 'الكثافة', 'السكانية', 'شخص', 'لكلّ', 'كيلو', 'متر', 'مربع،', 'تحتل', 'المغرب', 'المرتبة', 'عالمياً', 'عدد', 'السكان،', 'ويُمثّل', 'عددهم', 'نسبةً', 'تصل', 'إجماليّ', 'سكان', 'العالم،٥', 'ويتألّف', 'الشعب', 'المغربيّ', 'عدّة', 'فئات', 'عرقية', 'مختلفة،', 'أهمّها', 'العرب', 'والأمازيغ', 'وهم', 'السُّكان', 'الأصليون،', 'وأقليّات', 'الأوروبيين', 'المعروفين', 'باسم', 'المغاربة', 'البيض،', 'وهم', 'مغاربة', 'أصل', 'أوروبي', 'كالإسبان', 'والفرنسيين،', 'بالإضافة', 'مجموعة', 'اليهود٦', 'يُعدّ', 'نظام', 'الحكم', 'دولة', 'المغرب', 'ملكيّاً', 'دستوريّاً', 'أقرّه', 'الدستور', 'الأول', 'عام', 'م،', 'نظام', 'برلمانيّ', 'ديمقراطيّ', 'اجتماعيّ،', 'يُعتبر', 'الملك', 'صاحب', 'السلطة', 'العليا', 'الدولة،', 'والقائد', 'الأعلى', 'للقوات', 'المسلحة', 'الملكية،', 'ويرأس', 'المجلس', 'الأعلى', 'للقضاء،', 'ويمتلك', 'عدّة', 'صلاحيات', 'منها؛', 'تعيين', 'رئيس', 'الوزراء', 'إجراء', 'الانتخابات', 'التشريعية،', 'وإقالة', 'الوزراء،', 'وحلّ', 'مجلس', 'النواب', 'والحكومة،', 'يتألّف', 'البرلمان', 'المغربي', 'مجلسين', 'تشريعيين،', 'مجلس', 'النواب', 'يضم', 'عضواً', 'يتمّ', 'انتخابهم', 'لمدّة', 'أعوام،', 'ومجلس', 'المستشارين', 'يحوي', 'عضواً', 'الأقل', 'عضواً', 'الأكثر،', 'يتمّ', 'انتخابهم', 'بشكل', 'مباشر', 'لمدّة', 'سنوات٧', 'تتميز', 'المغرب', 'بمجموعةٍ', 'القطاعات', 'الصناعيّة', 'المتنوّعة', 'دور', 'بارز', 'التقليل', 'البطالة،', 'ونظراً', 'خصوبة', 'أراضيها؛', 'القطاع', 'الزراعيّ', 'يُهيمن', 'الاقتصاد،', 'ويُساهم', 'بنسبة', 'تصل', 'الناتج', 'المحليّ', 'الإجماليّ', 'ويُشغّل', 'حوالي', 'الأيدي', 'العاملة،', 'وبسبب', 'تأثيره', 'الكبير', 'النمو', 'الاقتصاديّ', 'فقد', 'أولته', 'الحكومة', 'المغربية', 'اهتماماً', 'بالغاً', 'طريق', 'مخطط', 'المغرب', 'الأخضر', 'وصندوق', 'التنمية', 'الفلاحية٨', 'يُعدّ', 'الفوسفات', 'أيضاً', 'مصدراً', 'للثروة', 'المغربية', 'قلّة', 'الموارد', 'المعدنية،', 'يُساهم', 'القطاع', 'الصناعيّ', 'بنسبة', 'تصل', 'الناتج', 'المحلي', 'الإجمالي', 'ويوظّف', 'القوى', 'العاملة،', 'القطاعات', 'الصناعية', 'الرئيسية؛', 'المنسوجات،', 'والسلع', 'الجلدية،', 'وتجهيز', 'الأغذية،', 'وتكرير', 'النفط،', 'بينما', 'تشهد', 'قطاعات', 'جديدة', 'ازدهاراً', 'واضحاً؛', 'كالكيمياء،', 'والسيارات،', 'والإلكترونيات،', 'وقطاع', 'الطيران،', 'قطاع', 'الخدمات', 'فيُمثّل', 'نصف', 'الناتج', 'المحلي', 'الإج ...

# %% [markdown]
# ## **Stemming** VS **Lemmatization**
#
# ---

# %% [markdown]
# ## Stemming :

# %% [markdown]
# **ISRIStemmer** :
# The ISRIStemmer is a stemming algorithm specifically designed for Arabic text. It applies a set of rules to reduce words to their base forms. While ISRIStemmer can effectively reduce words to their stems, it may occasionally produce stems that do not correspond to valid words in the Arabic language. This is because the algorithm focuses on morphological patterns rather than semantic meaning.

# %%
# Initialize ISRIStemmer
stemmer = ISRIStemmer()

# Stem the filtered Arabic tokens
stemmed_tokens = [stemmer.stem(w) for w in filtered_arabic_tokens]

print("Filtered Arabic Tokens (After Stop Words Removal and Stemming):")
print(stemmed_tokens)
# Out:
# Filtered Arabic Tokens (After Stop Words Removal and Stemming):
# ['ثقف', 'حول', 'غرب', 'تمت', 'كتب', 'بسط', 'حمد', 'مرو', 'اخر', 'حدث', '١٨٣١', '،', '٣', '٢٠٢١', 'تقع', 'غرب', 'قرة', 'ريقي،', 'حدد', 'وقع', 'جغراف', 'إحداث', 'درج', 'شمل', 'درج', 'غربا،', 'ان', 'سحل', 'حيط', 'طلس', 'بحر', 'ابض', 'توسط', 'فصل', 'بين', 'ضيق', 'جبل', 'طارق،', 'تحد', 'جنب', 'شرق', 'دول', 'جزائر،', 'جنب', 'جنب', 'جمهور', 'موريتانية،', 'يشر', 'ان', 'ساح', 'غرب', 'جمل', 'بلغ', 'حلي', 'كم١٢', 'تعد', 'دين', 'ربط', 'عصم', 'غرب،', 'يقم', 'حلي', 'مة،', 'وفق', 'إحصائ', 'شهر', 'عام', 'م،', 'وزع', 'ساح', 'بلغ', 'كم،', 'بلغ', 'كثف', 'سكن', 'شخص', 'لكل', 'كيلومتر', 'ربع،', 'طلق', 'دين', 'ربط', 'عدة', 'قب،', 'شنط', 'افريقيا؛', 'لأن', 'شرع', 'وسع', 'علم', 'ثري', 'مميزة،', 'ضفة', 'بني', 'حكم', 'نزل', 'تم', 'حول', 'دق،', 'سمى', 'ايض', 'بمد', 'زهر', 'حوئ', 'حدق', 'شسع', 'جميلة،', 'لقب', 'ربط', 'دين', 'يضء', 'نظر', 'بيئ', 'هادئة٣', 'عمد', 'غرب', 'علم', 'وطن', 'رسم', 'سبع', 'شهر', 'ثني', 'لعم', 'م،', 'رية', 'لون', 'حمر', 'فقط', 'اية', 'علم', 'خرى،', 'صمم', 'علم', 'غرب', 'سلط', 'وسف', 'حكم', 'بلد', 'عمي', 'م،', 'ألف', 'علم', 'طيل', 'لون', 'حمر', 'وسط', 'نجم', 'خمس', 'لون', 'خضر،', 'رمز', 'لون', 'حمر', 'شجع', 'قوة،', 'يشر', 'لون', 'خضر', 'دين', 'سلم', 'رمز', 'حب،', 'رح،', 'مل،', 'لم،', 'حكمة،', 'نجم', 'خمس', 'مثل', 'ارك', 'سلم', 'خمسة٤', 'بلغ', 'عدد', 'سكن', 'غرب', 'حسب', 'حصئ', 'امم', 'تحد', 'حتى', 'اليوم', 'ثني', 'شهر', 'لعم', 'مة،', 'توسط', 'عمر', 'عم،', 'تصل', 'كثف', 'سكن', 'شخص', 'لكل', 'كيلو', 'متر', 'ربع،', 'حتل', 'غرب', 'رتب', 'علم', 'عدد', 'كن،', 'مثل', 'عدد', 'نسب', 'تصل', 'جمل', 'سكن', 'عالم،٥', 'ألف', 'شعب', 'غرب', 'عدة', 'فئت', 'عرق', 'مختلفة،', 'اهم', 'عرب', 'ازغ', 'وهم', 'سكن', 'صليون،', 'أقل', 'ورب', 'عرف', 'بسم', 'غرب', 'يض،', 'وهم', 'غرب', 'اصل', 'ورب', 'اسب', 'فرنسيين،', 'ضفة', 'جمع', 'هود٦', 'يعد', 'نظم', 'حكم', 'دول', 'غرب', 'ملك', 'دستور', 'اقر', 'دستور', 'اول', 'عام', 'م،', 'نظم', 'رلم', 'ديمقراطي', 'اجتماعي،', 'عبر', 'ملك', 'صحب', 'سلط', 'علا', 'دولة،', 'قئد', 'على', 'قوت', 'سلح', 'ملكية،', 'رأس', 'جلس', 'على', 'قضء،', 'متل', 'عدة', 'صلح', 'نه؛', 'تعي', 'رئس', 'زرء', 'جرء', 'نخب', 'تشريعية،', 'إقل', 'زرء،', 'وحل', 'جلس', 'نوب', 'حكومة،', 'ألف', 'رلم', 'غرب', 'جلس', 'تشريعيين،', 'جلس', 'نوب', 'يضم', 'عضا', 'يتم', 'نخب', 'لمد', 'عم،', 'جلس', 'شار', 'يحي', 'عضا', 'اقل', 'عضا', 'كثر،', 'يتم', 'نخب', 'شكل', 'بشر', 'لمد', 'نت٧', 'تمز', 'غرب', 'جمع', 'قطع', 'صنع', 'تنع', 'دور', 'برز', 'قلل', 'طالة،', 'نظر', 'خصب', 'اراضيها؛', 'قطع', 'زرع', 'يهم', 'قتصاد،', 'ويس', 'نسب', 'تصل', 'نتج', 'حلي', 'جمل', 'شغل', 'حلي', 'ايد', 'عاملة،', 'سبب', 'أثر', 'كبر', 'نمو', 'قصد', 'فقد', 'اول', 'حكم', 'غرب', 'هما', 'بلغ', 'طرق', 'خطط', 'غرب', 'خضر', 'صندوق', 'نمي', 'حية٨', 'يعد', 'وسف', 'ايض', 'صدر', 'ثرة', 'غرب', 'قلة', 'ورد', 'معدنية،', 'يسا', 'قطع', 'صنع', 'نسب', 'تصل', 'نتج', 'حلي', 'جمل', 'وظف', 'قوى', 'عاملة،', 'قطع', 'صنع', 'رئيسية؛', 'منسوجات،', 'سلع', 'جلدية،', 'جهز', 'غذية،', 'كرر', 'فط،', 'بين', 'شهد', 'قطع', 'جدد', 'زدهار', 'ضح؛', 'كيمياء،', 'رت،', 'الكترونيات،', 'قطع', 'طيران،', 'قطع', 'خدم', 'مثل', 'نصف', 'نتج', 'حلي', 'جمل', 'وفر', 'فرص', 'عمل', 'نسب', 'ايد', 'عاملة٨', 'تمز', 'غرب', 'طبع', 'خلب', 'ريدة،', 'انه', 'تحي', 'غابات،', 'هول،', 'ين،', 'قمم', 'جبل', 'طلس،', 'صخر', 'صحر', 'رمل', 'جنوب،', 'ضفة', 'وقع', 'دين', 'خلف', 'يمكن', 'زيارتها،', 'ان', 'غرب', 'تعد', 'دول', 'نشر', 'سمح', 'عيش', 'دين،', 'نتج', 'لذلك', 'عدد', 'شكل', 'سيح', 'غرب', 'وع،', 'ملك', 'غرب', 'عدد', 'وقع', 'ارخ', 'ثري', 'درج', 'قئم', 'سكو', 'رث،', 'ومن', 'أي٩', 'تمز', 'عظم', 'نطق', 'وقع', 'صحراء', 'غرب', 'ناخ', 'حار', 'صيف', 'عدل', 'شتء،', 'سمر', 'وسم', 'مطر', 'شهر', 'اول', 'حتى', 'شهر', 'سن،', 'ركز', 'هطل', 'مطر', 'لد،', 'خفض', 'درج', 'حتى', 'جنوب،', 'يؤد', 'تير', 'كنر', 'يمر', 'قبل', 'شطئ', 'غرب', 'قرر', 'حلة', 'جوية٢١٠', 'عبر', 'غرب', 'موط', 'ازغ', 'قرب', 'عام', 'ميلاد،', 'وفي', 'عام', 'ضمت', 'روم', 'موريتانيا،', 'أصبح', 'جزء', 'جاح', 'دل،', 'عام', 'يطر', 'عليها', 'عرب،', 'بعد', 'يطر', 'عليها', 'كل', 'سبن', 'رتغال', 'وحد', 'قبل', 'دفع', 'اراضيها،', 'وفي', 'عام', 'غرب', 'حكم', 'علويين١١', 'تم', 'رسل', 'جح،', 'شكر', 'حقق', 'حفظ', 'وضع', 'حقق', 'حفظ', 'وض ...

# %% [markdown]
# **SnowballStemmer** **for** **Arabic** :
# SnowballStemmer is a popular stemming algorithm available for various languages, including Arabic. It uses a set of rules and heuristics to truncate words to their root forms. Similar to ISRIStemmer, SnowballStemmer may generate stems that are not valid Arabic words due to its rule-based approach.

# %%
nltk.download('snowball_data')

# Initialize SnowballStemmer for Arabic
stemmer = SnowballStemmer("arabic")

# %%
# Stem Arabic tokens
stemmed_tokens = [stemmer.stem(token) for token in filtered_arabic_tokens]

print("Filtered Arabic Tokens (After Stop Words Removal and Stemming):")
print(stemmed_tokens)
# Out:
# Filtered Arabic Tokens (After Stop Words Removal and Stemming):
# ['ثقاف', 'حول', 'مغرب', 'تمت', 'كتاب', 'واسط', 'محمد', 'مروا', 'اخر', 'تحديث', '١٨٣١', '', '٣', '٢٠٢١', 'تقع', 'مغرب', 'قار', 'افريق', 'يتحدد', 'موقع', 'جغراف', 'احداث', 'درج', 'شمال', 'درج', 'غرب', 'إن', 'سواحل', 'محيط', 'اطلس', 'بحر', 'ابيض', 'متوسط', 'يفصل', 'بين', 'مضيق', 'جبل', 'طارق', 'تحد', 'جانب', 'شرق', 'دول', 'جزاير', 'جانب', 'جنوب', 'جمهور', 'موريتان', 'يشار', 'أن', 'مساح', 'مغرب', 'اجمال', 'تبلغ', 'حوال', 'كم١٢', 'تعد', 'مدين', 'رباط', 'عاصم', 'مغرب', 'يقيم', 'حوال', 'نسم', 'وفق', 'احصاء', 'شهر', 'عام', 'م', 'يتوزع', 'مساح', 'تبلغ', 'كم', 'تبلغ', 'كثاف', 'سكان', 'شخص', 'لكل', 'يلومتر', 'مربع', 'يطلق', 'مدين', 'رباط', 'عد', 'القاب', 'واشنط', 'افريق', 'لان', 'شوارع', 'واسع', 'معالم', 'اثر', 'مميز', 'اضاف', 'مبان', 'حكوم', 'منازل', 'تم', 'تحويل', 'نادق', 'تسمى', 'ايض', 'مدين', 'زهور', 'احتواء', 'حدايق', 'شاسع', 'جميل', 'تلقب', 'رباط', 'مدين', 'بيضاء', 'نظر', 'بيء', 'هادية٣', 'اعتمد', 'مغرب', 'علم', 'وطن', 'رسم', 'سابع', 'شهر', 'ثان', 'لعام', 'م', 'را', 'الل', 'احمر', 'فقط', 'اي', 'علام', 'اخرى', 'صمم', 'علم', 'مغرب', 'سلط', 'يوسف', 'حكم', 'بلاد', 'عام', 'م', 'يتالف', 'علم', 'مستطيل', 'الل', 'احمر', 'تتوسط', 'نجم', 'خماس', 'الل', 'اخضر', 'يرمز', 'لون', 'احمر', 'شجاع', 'والقو', 'يشير', 'لون', 'اخضر', 'دين', 'اسلام', 'يرمز', 'للحب', 'فرح', 'امل', 'سلام', 'حكم', 'نجم', 'خماس', 'تمثل', 'اركا', 'اسلام', 'خمسة٤', 'يبلغ', 'عدد', 'سكا', 'مغرب', 'حسب', 'احصاء', 'امم', 'متحد', 'حتى', 'يوم', 'ثان', 'شهر', 'لعام', 'نسم', 'متوسط', 'عمر', 'عام', 'تصل', 'كثاف', 'سكان', 'شخص', 'لكل', 'كيل', 'متر', 'مربع', 'تحتل', 'مغرب', 'مرتب', 'عالم', 'عدد', 'السك', 'يمثل', 'عدد', 'نسب', 'تصل', 'اجمال', 'سكا', 'عالم٥', 'يتالف', 'شعب', 'مغرب', 'عد', 'فيا', 'عرق', 'مختلف', 'اهم', 'عرب', 'امازيغ', 'وهم', 'السك', 'اصل', 'اقل', 'اوروب', 'معروف', 'اسم', 'مغارب', 'بيض', 'وهم', 'مغارب', 'اصل', 'اوروب', 'اسب', 'فرنس', 'اضاف', 'مجموع', 'يهود٦', 'يعد', 'نظام', 'حكم', 'دول', 'مغرب', 'ملك', 'دستور', 'اقر', 'دستور', 'اول', 'عام', 'م', 'نظام', 'رلم', 'ديمقراط', 'اجتماع', 'يعتبر', 'ملك', 'صاحب', 'سلط', 'العل', 'دول', 'قايد', 'اعلى', 'للقو', 'مسلح', 'ملك', 'يراس', 'مجلس', 'اعلى', 'قضاء', 'يمتل', 'عد', 'صلاح', 'منه', 'تع', 'رييس', 'وزراء', 'اجراء', 'انتخاب', 'تشريع', 'اقال', 'وزراء', 'وحل', 'مجلس', 'نواب', 'حكوم', 'يتالف', 'برلم', 'مغرب', 'مجلس', 'تشريع', 'مجلس', 'نواب', 'يضم', 'عضو', 'يتم', 'انتخاب', 'لمد', 'اعوام', 'مجلس', 'مستشار', 'يحو', 'عضو', 'اقل', 'عضو', 'اكثر', 'يتم', 'انتخاب', 'شكل', 'مباشر', 'لمد', 'سنوات٧', 'تتميز', 'مغرب', 'مجموع', 'قطاع', 'صناع', 'متنوع', 'دور', 'ارز', 'تقليل', 'بطال', 'نظر', 'خصوب', 'اراض', 'قطاع', 'زراع', 'يهيم', 'اقتصاد', 'ويس', 'نسب', 'تصل', 'ناتج', 'محل', 'اجمال', 'يشغل', 'حوال', 'ايد', 'عامل', 'سبب', 'تاثير', 'كبير', 'نمو', 'اقتصاد', 'فقد', 'اول', 'حكوم', 'مغرب', 'اهتمام', 'بال', 'طريق', 'مخطط', 'مغرب', 'اخضر', 'صندوق', 'تنم', 'فلاحية٨', 'يعد', 'فوسف', 'ايض', 'مصدر', 'ثرو', 'مغرب', 'قل', 'موارد', 'معدن', 'يسا', 'قطاع', 'صناع', 'نسب', 'تصل', 'ناتج', 'محل', 'اجمال', 'يوظف', 'قوى', 'عامل', 'قطاع', 'صناع', 'رييس', 'منسوج', 'سلع', 'جلد', 'تجهيز', 'اغذ', 'تكرير', 'نفط', 'ينم', 'تشهد', 'قطاع', 'جديد', 'ازدهار', 'واضح', 'يمياء', 'سيار', 'الكترون', 'قطاع', 'طير', 'قطاع', 'خدم', 'يمثل', 'نصف', 'ناتج', 'محل', 'اجمال', 'يوفر', 'فرص', 'عمل', 'نسب', 'ايد', 'عاملة٨', 'تتميز', 'مغرب', 'طبيع', 'خلاب', 'فريد', 'انه', 'تحو', 'غاب', 'سهول', 'والبس', 'قمم', 'جبال', 'اطلس', 'صخور', 'صحار', 'رمل', 'جنوب', 'اضاف', 'مواقع', 'دين', 'مختلف', 'يمك', 'زيار', 'إن', 'مغرب', 'تعد', 'دول', 'ينتشر', 'تسامح', 'تعايش', 'الاد', 'نتيج', 'لذل', 'تتتعدد', 'اشكال', 'سياح', 'مغرب', 'تتنوع', 'تمتل', 'مغرب', 'عديد', 'مواقع', 'تاريخ', 'اثر', 'مدرج', 'قايم', 'يونسكو', 'تراث', 'ومن', 'ياتي٩', 'تتميز', 'معظم', 'مناطق', 'واقع', 'صحراء', 'غرب', 'مناخ', 'حار', 'صيف', 'معتدل', 'شتاء', 'يستمر', 'موسم', 'امطار', 'شهر', 'اول', 'حتى', 'شهر', 'نيسا', 'يتركز', 'هطول', 'امطار', 'بلاد', 'ينخفض', 'تدريج', 'حتى', 'جنوب', 'يود', 'تيار', 'كنار', 'يمر', 'قبال', 'شواطء', 'مغرب', 'استقرار', 'حال', 'جوية٢١٠', 'تعتبر', 'مغرب', 'موط', 'امازيغ', 'يقارب', 'عام', 'ميلاد', 'وف', 'عام', 'ضمت', 'روم', 'مو ...

# %% [markdown]
# **ARLSTem** :
# ARLSTem is another stemming algorithm for Arabic text processing. It aims to improve upon the limitations of ISRIStemmer and SnowballStemmer by considering linguistic and semantic factors in addition to morphological patterns. However, like other stemming methods, it may still produce stems that deviate from actual dictionary entries.

# %%
# Initialize ARLSTem
stemmmer = ARLSTem()

# Stem Arabic tokens
stemmed_tokens = [stemmer.stem(token) for token in filtered_arabic_tokens]

print("Filtered Arabic Tokens (After Stop Words Removal and Stemming):")
print(stemmed_tokens)
# Out:
# Filtered Arabic Tokens (After Stop Words Removal and Stemming):
# ['ثقاف', 'حول', 'مغرب', 'تمت', 'كتاب', 'واسط', 'محمد', 'مروا', 'اخر', 'تحديث', '١٨٣١', '', '٣', '٢٠٢١', 'تقع', 'مغرب', 'قار', 'افريق', 'يتحدد', 'موقع', 'جغراف', 'احداث', 'درج', 'شمال', 'درج', 'غرب', 'إن', 'سواحل', 'محيط', 'اطلس', 'بحر', 'ابيض', 'متوسط', 'يفصل', 'بين', 'مضيق', 'جبل', 'طارق', 'تحد', 'جانب', 'شرق', 'دول', 'جزاير', 'جانب', 'جنوب', 'جمهور', 'موريتان', 'يشار', 'أن', 'مساح', 'مغرب', 'اجمال', 'تبلغ', 'حوال', 'كم١٢', 'تعد', 'مدين', 'رباط', 'عاصم', 'مغرب', 'يقيم', 'حوال', 'نسم', 'وفق', 'احصاء', 'شهر', 'عام', 'م', 'يتوزع', 'مساح', 'تبلغ', 'كم', 'تبلغ', 'كثاف', 'سكان', 'شخص', 'لكل', 'يلومتر', 'مربع', 'يطلق', 'مدين', 'رباط', 'عد', 'القاب', 'واشنط', 'افريق', 'لان', 'شوارع', 'واسع', 'معالم', 'اثر', 'مميز', 'اضاف', 'مبان', 'حكوم', 'منازل', 'تم', 'تحويل', 'نادق', 'تسمى', 'ايض', 'مدين', 'زهور', 'احتواء', 'حدايق', 'شاسع', 'جميل', 'تلقب', 'رباط', 'مدين', 'بيضاء', 'نظر', 'بيء', 'هادية٣', 'اعتمد', 'مغرب', 'علم', 'وطن', 'رسم', 'سابع', 'شهر', 'ثان', 'لعام', 'م', 'را', 'الل', 'احمر', 'فقط', 'اي', 'علام', 'اخرى', 'صمم', 'علم', 'مغرب', 'سلط', 'يوسف', 'حكم', 'بلاد', 'عام', 'م', 'يتالف', 'علم', 'مستطيل', 'الل', 'احمر', 'تتوسط', 'نجم', 'خماس', 'الل', 'اخضر', 'يرمز', 'لون', 'احمر', 'شجاع', 'والقو', 'يشير', 'لون', 'اخضر', 'دين', 'اسلام', 'يرمز', 'للحب', 'فرح', 'امل', 'سلام', 'حكم', 'نجم', 'خماس', 'تمثل', 'اركا', 'اسلام', 'خمسة٤', 'يبلغ', 'عدد', 'سكا', 'مغرب', 'حسب', 'احصاء', 'امم', 'متحد', 'حتى', 'يوم', 'ثان', 'شهر', 'لعام', 'نسم', 'متوسط', 'عمر', 'عام', 'تصل', 'كثاف', 'سكان', 'شخص', 'لكل', 'كيل', 'متر', 'مربع', 'تحتل', 'مغرب', 'مرتب', 'عالم', 'عدد', 'السك', 'يمثل', 'عدد', 'نسب', 'تصل', 'اجمال', 'سكا', 'عالم٥', 'يتالف', 'شعب', 'مغرب', 'عد', 'فيا', 'عرق', 'مختلف', 'اهم', 'عرب', 'امازيغ', 'وهم', 'السك', 'اصل', 'اقل', 'اوروب', 'معروف', 'اسم', 'مغارب', 'بيض', 'وهم', 'مغارب', 'اصل', 'اوروب', 'اسب', 'فرنس', 'اضاف', 'مجموع', 'يهود٦', 'يعد', 'نظام', 'حكم', 'دول', 'مغرب', 'ملك', 'دستور', 'اقر', 'دستور', 'اول', 'عام', 'م', 'نظام', 'رلم', 'ديمقراط', 'اجتماع', 'يعتبر', 'ملك', 'صاحب', 'سلط', 'العل', 'دول', 'قايد', 'اعلى', 'للقو', 'مسلح', 'ملك', 'يراس', 'مجلس', 'اعلى', 'قضاء', 'يمتل', 'عد', 'صلاح', 'منه', 'تع', 'رييس', 'وزراء', 'اجراء', 'انتخاب', 'تشريع', 'اقال', 'وزراء', 'وحل', 'مجلس', 'نواب', 'حكوم', 'يتالف', 'برلم', 'مغرب', 'مجلس', 'تشريع', 'مجلس', 'نواب', 'يضم', 'عضو', 'يتم', 'انتخاب', 'لمد', 'اعوام', 'مجلس', 'مستشار', 'يحو', 'عضو', 'اقل', 'عضو', 'اكثر', 'يتم', 'انتخاب', 'شكل', 'مباشر', 'لمد', 'سنوات٧', 'تتميز', 'مغرب', 'مجموع', 'قطاع', 'صناع', 'متنوع', 'دور', 'ارز', 'تقليل', 'بطال', 'نظر', 'خصوب', 'اراض', 'قطاع', 'زراع', 'يهيم', 'اقتصاد', 'ويس', 'نسب', 'تصل', 'ناتج', 'محل', 'اجمال', 'يشغل', 'حوال', 'ايد', 'عامل', 'سبب', 'تاثير', 'كبير', 'نمو', 'اقتصاد', 'فقد', 'اول', 'حكوم', 'مغرب', 'اهتمام', 'بال', 'طريق', 'مخطط', 'مغرب', 'اخضر', 'صندوق', 'تنم', 'فلاحية٨', 'يعد', 'فوسف', 'ايض', 'مصدر', 'ثرو', 'مغرب', 'قل', 'موارد', 'معدن', 'يسا', 'قطاع', 'صناع', 'نسب', 'تصل', 'ناتج', 'محل', 'اجمال', 'يوظف', 'قوى', 'عامل', 'قطاع', 'صناع', 'رييس', 'منسوج', 'سلع', 'جلد', 'تجهيز', 'اغذ', 'تكرير', 'نفط', 'ينم', 'تشهد', 'قطاع', 'جديد', 'ازدهار', 'واضح', 'يمياء', 'سيار', 'الكترون', 'قطاع', 'طير', 'قطاع', 'خدم', 'يمثل', 'نصف', 'ناتج', 'محل', 'اجمال', 'يوفر', 'فرص', 'عمل', 'نسب', 'ايد', 'عاملة٨', 'تتميز', 'مغرب', 'طبيع', 'خلاب', 'فريد', 'انه', 'تحو', 'غاب', 'سهول', 'والبس', 'قمم', 'جبال', 'اطلس', 'صخور', 'صحار', 'رمل', 'جنوب', 'اضاف', 'مواقع', 'دين', 'مختلف', 'يمك', 'زيار', 'إن', 'مغرب', 'تعد', 'دول', 'ينتشر', 'تسامح', 'تعايش', 'الاد', 'نتيج', 'لذل', 'تتتعدد', 'اشكال', 'سياح', 'مغرب', 'تتنوع', 'تمتل', 'مغرب', 'عديد', 'مواقع', 'تاريخ', 'اثر', 'مدرج', 'قايم', 'يونسكو', 'تراث', 'ومن', 'ياتي٩', 'تتميز', 'معظم', 'مناطق', 'واقع', 'صحراء', 'غرب', 'مناخ', 'حار', 'صيف', 'معتدل', 'شتاء', 'يستمر', 'موسم', 'امطار', 'شهر', 'اول', 'حتى', 'شهر', 'نيسا', 'يتركز', 'هطول', 'امطار', 'بلاد', 'ينخفض', 'تدريج', 'حتى', 'جنوب', 'يود', 'تيار', 'كنار', 'يمر', 'قبال', 'شواطء', 'مغرب', 'استقرار', 'حال', 'جوية٢١٠', 'تعتبر', 'مغرب', 'موط', 'امازيغ', 'يقارب', 'عام', 'ميلاد', 'وف', 'عام', 'ضمت', 'روم', 'مو ...

# %% [markdown]
# ## Lemmatization :

# %% [markdown]
# **Farasa API** :
# Farasa is an Arabic NLP toolkit that provides lemmatization functionality through its web API. It leverages machine learning models and linguistic resources to accurately map words to their base forms. Unlike stemming, lemmatization considers the context and meaning of words, resulting in more accurate normalization. However, it may introduce computational overhead due to its reliance on external resources.

# %%
# Define the URL of the Farasa lemmatization API
url = 'https://farasa.qcri.org/webapi/lemmatization/'

# API key provided by Farasa
api_key = "EkhjeVroQrUHSKjdfI"

# Prepare the payload data
payload = {'text': ' '.join(filtered_arabic_tokens), 'api_key': api_key}

# Send a POST request to the Farasa lemmatization API
response = requests.post(url, data=payload)

# Parse the JSON response
result = json.loads(response.text)

# Extract the list of tokens
tokens = result.get('text', [])

# Remove '،' from each token
tokens_lemma = [token.replace('،', '') for token in tokens]

# Filter out empty tokens
tokens_lemma = [token for token in tokens_lemma if token]

# Print the list of tokens
print(tokens_lemma)
# Out:
# ['ثقافة', 'حول', 'مغرب', 'تم', 'كتابة', 'واسطة', 'محمد', 'مروان', 'آخر', 'تحديث', '1831', '3', '2021', 'وقع', 'مغرب', 'قارة', 'أفريقي', 'تحدد', 'موقع', 'جغرافي', 'إحداثي', 'درجة', 'شمال', 'درجة', 'غرب', 'إن', 'ساحل', 'محيط', 'أطلسي', 'بحر', 'أبيض', 'متوسط', 'فصل', 'بين', 'مضيق', 'جبل', 'طارق', 'حد', 'جانب', 'شرقي', 'دولة', 'جزائر', 'جانب', 'جنوبي', 'جمهورية', 'موريتاني', 'أشار', 'أن', 'مساحة', 'مغرب', 'إجمالي', 'بلغ', 'حوالي', 'كم', '12', 'عد', 'مدينة', 'رباط', 'عاصمة', 'مغرب', 'أقام', 'حوالي', 'نسمة', 'وفق', 'إحصائي', 'شهر', 'عام', 'م', 'توزع', 'مساحة', 'بلغ', 'كم', 'بلغ', 'كثافة', 'سكاني', 'شخص', 'كل', 'كيلومتر', 'مربع', 'أطلق', 'مدينة', 'رباط', 'عدة', 'لقب', 'واشنطون', 'أفريقيا', '؛', 'أن', 'شارع', 'واسع', 'معلم', 'أثري', 'مميز', 'إضافة', 'مبنى', 'حكومي', 'منزل', 'تم', 'تحويل', 'فندق', 'سمى', 'أيض', 'مدينة', 'زهور', 'احتواء', 'حديقة', 'شاسع', 'جميل', 'تلقب', 'رباط', 'مدينة', 'أبيض', 'نظر', 'بيئة', 'هادئ', '3', 'اعتمد', 'مغرب', 'علم', 'وطني', 'رسمي', 'سابع', 'شهر', 'ثاني', 'عام', 'م', 'راية', 'لون', 'أحمر', 'فقط', 'أي', 'علامة', 'آخر', 'صمم', 'علم', 'مغربي', 'سلطان', 'يوسف', 'حكم', 'بلد', 'عام', 'م', 'تألف', 'علم', 'مستطيل', 'لون', 'أحمر', 'توسط', 'نجمة', 'خماسي', 'لون', 'أخضر', 'رمز', 'لون', 'أحمر', 'شجاعة', 'قوة', 'أشار', 'لون', 'أخضر', 'دين', 'إسلامي', 'رمز', 'حب', 'فرح', 'أمل', 'سلام', 'حكمة', 'نجمة', 'خماسي', 'تمثل', 'ركن', 'إسلام', 'خمس', '4', 'بلغ', 'عدد', 'ساكن', 'مغرب', 'حسب', 'إحصائي', 'أمة', 'متحد', 'حتى', 'يوم', 'ثاني', 'شهر', 'عام', 'نسمة', 'متوسط', 'عمر', 'عام', 'وصل', 'كثافة', 'سكاني', 'شخص', 'كل', 'كيلو', 'متر', 'مربع', 'احتل', 'مغرب', 'مرتبة', 'عالمي', 'عدد', 'ساكن', 'مثل', 'عدد', 'نسبة', 'وصل', 'إجمالي', 'ساكن', 'عالم', '5', 'تألف', 'شعب', 'مغربي', 'عدة', 'فئة', 'عرقي', 'مختلف', 'أهم', 'عربي', 'أمازيغ', 'هم', 'ساكن', 'أصلي', 'أقلية', 'أوربي', 'معروف', 'اسم', 'مغربي', 'بيض', 'هم', 'مغربي', 'أصل', 'أوربي', 'إسباني', 'فرنسي', 'إضافة', 'مجموعة', 'يهودي', '6', 'عد', 'نظام', 'حكم', 'دولة', 'مغرب', 'ملكي', 'دستوري', 'أقر', 'دستور', 'أول', 'عام', 'م', 'نظام', 'برلماني', 'ديموقراطي', 'اجتماعي', 'اعتبر', 'ملك', 'صاحب', 'سلطة', 'أعلى', 'دولة', 'قائد', 'أعلى', 'قوة', 'مسلح', 'ملكية', 'رأس', 'مجلس', 'أعلى', 'قضاء', 'امتلك', 'عدة', 'صلاحية', 'من', '؛', 'تعيين', 'رئيس', 'وزير', 'إجراء', 'انتخاب', 'تشريعي', 'إقالة', 'وزير', 'حل', 'مجلس', 'نائب', 'حكومة', 'تألف', 'برلمان', 'مغربي', 'مجلس', 'تشريعي', 'مجلس', 'نائب', 'ضم', 'عضو', 'تم', 'انتخاب', 'مدة', 'عام', 'مجلس', 'مستشار', 'حوى', 'عضو', 'أقل', 'عضو', 'أكثر', 'تم', 'انتخاب', 'شكل', 'مباشر', 'مدة', 'سنة', '7', 'تميز', 'مغرب', 'مجموعة', 'قطاع', 'صناعي', 'متنوع', 'دور', 'بارز', 'تقليل', 'بطالة', 'نظر', 'خصوبة', 'أرض', '؛', 'قطاع', 'زراعي', 'هيمن', 'اقتصاد', 'ساهم', 'نسبة', 'وصل', 'ناتج', 'محلي', 'إجمالي', 'شغل', 'حوالي', 'يد', 'عامل', 'سبب', 'تأثير', 'كبير', 'نمو', 'اقتصادي', 'قد', 'أولى', 'حكومة', 'مغربي', 'اهتمام', 'بالغ', 'طريق', 'مخطط', 'مغرب', 'أخضر', 'صندوق', 'تنمية', 'فلاحي', '8', 'عد', 'فوسفات', 'أيض', 'مصدر', 'ثروة', 'مغربي', 'قلة', 'مورد', 'معدني', 'ساهم', 'قطاع', 'صناعي', 'نسبة', 'وصل', 'ناتج', 'محلي', 'إجمالي', 'وظف', 'قوة', 'عامل', 'قطاع', 'صناعي', 'رئيسي', '؛', 'منسوج', 'سلعة', 'جلدي', 'تجهيز', 'غذاء', 'تكرير', 'نفط', 'بين', 'شهد', 'قطاع', 'جديد', 'ازدهار', 'واضح', '؛', 'كيمياء', 'سيارة', 'إلكتروني', 'قطاع', 'طيران', 'قطاع', 'خدمة', 'مثل', 'نصف', 'ناتج', 'محلي', 'إجمالي', 'وفر', 'فرصة', 'عمل', 'نسبة', 'يد', 'عامل', '8', 'تميز', 'مغرب', 'طبيعة', 'خلاب', 'فريد', 'إن', 'حوى', 'غابة', 'سهل', 'بستان', 'قمة', 'جبل', 'أطلس', 'صخر', 'صحاري', 'رملي', 'جنوب', 'إضافة', 'موقع', 'ديني', 'مختلف', 'أمكن', 'زيارة', 'إن', 'مغرب', 'عد', 'دولة', 'انتشر', 'تسامح', 'تعايش', 'دين', 'نتيجة', 'ذلك', 'تتتعدد', 'شكل', 'سياحة', 'مغرب', 'تنوع', 'امتلك', 'مغرب', 'عديد', 'موقع', 'تاريخي', 'أثري', 'مدرج', 'قائمة', 'يونسكو', 'تراث', 'من', 'أتى', '9', 'تميز', 'معظم', 'منطقة', 'واقع', 'صحراء', 'غربي', 'مناخ', 'حار', 'صيف', 'معتدل', 'شتاء', 'استمر', 'موسم', 'مطر', 'شهر', 'أول', 'حتى', 'شهر', 'نيسان', 'تركز', 'هطول', 'مطر', 'بلد', 'انخفض', 'تدريجي', 'حتى', 'جنوب', 'أدى', 'تيار', 'كنار', 'مر', 'قبا ...

# %% [markdown]
# **Comparison** :
#
# *   Stemming methods such as ISRIStemmer, SnowballStemmer, and ARLSTem offer fast and lightweight normalization of Arabic text but may produce stems that are not valid words. For example, when stemming the word 'والبرتغال' (meaning 'and Portugal'), the Farasa API yields 'برتغال', which is a valid Arabic word, while the other stemmers provide 'رتغال', which may not be recognized as a valid word. Similarly, for the word 'إسبانيا' (meaning 'Spain'), the stemmers output 'سبن', whereas the Farasa API retains the original word, 'إسبانيا'. These examples highlight instances where the Farasa API preserves the semantic integrity of the words while the stemmers prioritize morphological reduction, sometimes resulting in stems that do not correspond to valid entries in the Arabic language.
#
# *   Lemmatization with Farasa API provides more accurate normalization by considering semantics and context, but it may be slower and require internet connectivity.
#
# In summary, the choice between stemming and lemmatization depends on the specific requirements of the NLP task. While stemming is suitable for general text processing tasks that prioritize speed and simplicity, lemmatization is preferred for applications where accuracy and semantic fidelity are paramount.

# %% [markdown]
# ---
#
#
# ## Parts of Speech (POS) :

# %% [markdown]
# Rule Based Approach :

# %%
# Define rules for part-of-speech tagging using regular expressions
patterns = [
    (r'^ال.*$', 'اسم'),            # Nouns starting with ال
    (r'^و.*$', 'اسم'),              # Nouns starting with و
    (r'^ب.*$', 'اسم'),              # Nouns starting with ب
    (r'^ف.*$', 'اسم'),              # Nouns starting with ف
    (r'^ك.*$', 'اسم'),              # Nouns starting with ك
    (r'^ل.*$', 'اسم'),              # Nouns starting with ل
    (r'^م.*$', 'اسم'),              # Nouns starting with م
    (r'^ن.*$', 'اسم'),              # Nouns starting with ن
    (r'^ت.*$', 'اسم'),              # Nouns starting with ت
    (r'^ه.*$', 'اسم'),              # Nouns starting with ه
    (r'^ي.*$', 'اسم'),              # Nouns starting with ي
    (r'^ع.*$', 'اسم'),              # Nouns starting with ع
    (r'^ص.*$', 'اسم'),              # Nouns starting with ص
    (r'^ح.*$', 'اسم'),              # Nouns starting with ح
    (r'^ق.*$', 'اسم'),              # Nouns starting with ق
    (r'^ر.*$', 'اسم'),              # Nouns starting with ر
    (r'^س.*$', 'اسم'),              # Nouns starting with س
    (r'^ش.*$', 'اسم'),              # Nouns starting with ش
    (r'^ض.*$', 'اسم'),              # Nouns starting with ض
    (r'^ظ.*$', 'اسم'),              # Nouns starting with ظ
    (r'^غ.*$', 'اسم'),              # Nouns starting with غ
    (r'^هذا$', 'اسم'),             # Specific words like هذا
    (r'^هذه$', 'اسم'),             # Specific words like هذه
    (r'^هو$', 'ضمير'),              # Specific pronouns like هو
    (r'^هي$', 'ضمير'),              # Specific pronouns like هي
    (r'.*ُ$', 'اسم'),               # Nouns ending with ُ
    (r'.*َة$', 'اسم'),              # Nouns ending with َة
    (r'.*ِ$', 'فعل'),               # Verbs ending with ِ
    (r'.*َ$', 'صفة'),               # Adjectives ending with َ
    (r'.*َةُ$', 'اسم'),            # Nouns ending with َةُ
    (r'.*َةِ$', 'اسم'),            # Nouns ending with َةِ
    (r'.*ُون$', 'اسم'),            # Nouns ending with ُون
    (r'.*ِين$', 'اسم'),            # Nouns ending with ِين
    (r'.*ْ$', 'اسم'),              # Nouns ending with ْ
    (r'.*ى$', 'ضمير'),              # Pronouns ending with ى
    (r'.*َه$', 'ضمير'),             # Pronouns ending with ه
    (r'.*ت$', 'فعل'),              # Verbs ending with ت
    (r'.*نا$', 'ضمير'),             # Pronouns ending with نا
    (r'.*ك$', 'ضمير'),              # Pronouns ending with ك
    (r'.*ي$', 'ضمير'),              # Pronouns ending with ي
    (r'.*ُو$', 'ضمير'),             # Pronouns ending with ُو
    (r'.*ها$', 'ضمير'),             # Pronouns ending with ها
    (r'.*كما$', 'ضمير'),            # Pronouns ending with كما
    (r'.*كن$', 'ضمير'),             # Pronouns ending with كن
    (r'.*كم$', 'ضمير'),             # Pronouns ending with كم
    (r'.*ني$', 'ضمير'),             # Pronouns ending with ني
    (r'.*هما$', 'ضمير'),            # Pronouns ending with هما
    (r'.*هم$', 'ضمير'),             # Pronouns ending with هم
    (r'.*هن$', 'ضمير'),             # Pronouns ending with هن
    (r'.*ه$', 'ضمير'),              # Pronouns ending with ه
    (r'.*تا$', 'فعل'),              # Verbs ending with تا
    (r'.*تما$', 'فعل'),             # Verbs ending with تما
    (r'.*وا$', 'فعل'),              # Verbs ending with وا
    (r'.*ن$', 'فعل'),               # Verbs ending with ن
    (r'.*ه$', 'فعل'),               # Verbs ending with ه
    (r'.*و$', 'فعل'),               # Verbs ending with و
    (r'.*ي$', 'فعل'),               # Verbs ending with ي
    (r'^\w+$', 'اسم')               # Default to NOUN if no pattern matches
]

# Compile the patterns into a tagger
regexp_tagger = nltk.RegexpTagger(patterns)

# Tag the words using the rule-based tagger
tagged_words = regexp_tagger.tag(filtered_arabic_tokens)

# Print the tagged words
print(tagged_words)
# Out:
# [('ثقافة', 'اسم'), ('حول', 'اسم'), ('المغرب', 'اسم'), ('تمت', 'اسم'), ('الكتابة', 'اسم'), ('بواسطة', 'اسم'), ('محمد', 'اسم'), ('مروان', 'اسم'), ('آخر', 'اسم'), ('تحديث', 'اسم'), ('١٨٣١', 'اسم'), ('،', None), ('٣', 'اسم'), ('٢٠٢١', 'اسم'), ('تقع', 'اسم'), ('المغرب', 'اسم'), ('قارة', 'اسم'), ('أفريقي،', None), ('ويتحدّد', 'اسم'), ('موقعها', 'اسم'), ('جغرافياً', None), ('بإحداثيات', 'اسم'), ('درجة', 'اسم'), ('شمالاً', 'اسم'), ('درجات', 'فعل'), ('غرباً،', 'اسم'), ('إنّ', None), ('سواحل', 'اسم'), ('المحيط', 'اسم'), ('الأطلسي', 'اسم'), ('والبحر', 'اسم'), ('الأبيض', 'اسم'), ('المتوسط', 'اسم'), ('يفصل', 'اسم'), ('بينهما', 'اسم'), ('مضيق', 'اسم'), ('جبل', 'اسم'), ('طارق،', None), ('تحدُّها', 'اسم'), ('الجانب', 'اسم'), ('الشرقي', 'اسم'), ('دولة', 'اسم'), ('الجزائر،', 'اسم'), ('الجانب', 'اسم'), ('الجنوبيّ', 'اسم'), ('الجمهورية', 'اسم'), ('الموريتانية،', 'اسم'), ('ويُشار', 'اسم'), ('أنّ', None), ('مساحة', 'اسم'), ('المغرب', 'اسم'), ('الإجمالية', 'اسم'), ('تبلغ', 'اسم'), ('حوالي', 'اسم'), ('كم١٢', 'اسم'), ('تُعدّ', 'اسم'), ('مدينة', 'اسم'), ('الرباط', 'اسم'), ('عاصمة', 'اسم'), ('المغرب،', 'اسم'), ('ويُقيم', 'اسم'), ('حوالي', 'اسم'), ('نسمة،', 'اسم'), ('وفقاً', 'اسم'), ('لإحصائيات', 'اسم'), ('شهر', 'اسم'), ('عام', 'اسم'), ('م،', 'اسم'), ('يتوزّعون', 'اسم'), ('مساحة', 'اسم'), ('تبلغ', 'اسم'), ('كم،', 'اسم'), ('تبلغ', 'اسم'), ('الكثافة', 'اسم'), ('السكانية', 'اسم'), ('شخص', 'اسم'), ('لكلّ', 'اسم'), ('كيلومتر', 'اسم'), ('مربع،', 'اسم'), ('ويُطلق', 'اسم'), ('مدينة', 'اسم'), ('الرباط', 'اسم'), ('عدّة', 'اسم'), ('ألقاب،', None), ('واشنطن', 'اسم'), ('أفريقيا؛', None), ('لأنّ', 'اسم'), ('شوارعها', 'اسم'), ('واسعة', 'اسم'), ('ومعالمها', 'اسم'), ('الأثرية', 'اسم'), ('مميزة،', 'اسم'), ('بالإضافة', 'اسم'), ('مبانيها', 'اسم'), ('الحكومية', 'اسم'), ('والمنازل', 'اسم'), ('تمّ', 'اسم'), ('تحويلها', 'اسم'), ('فنادق،', 'اسم'), ('وتُسمّى', 'اسم'), ('أيضاً', None), ('بمدينة', 'اسم'), ('الزهور', 'اسم'), ('لاحتوائها', 'اسم'), ('حدائق', 'اسم'), ('شاسعة', 'اسم'), ('وجميلة،', 'اسم'), ('تُلقّب', 'اسم'), ('الرباط', 'اسم'), ('بالمدينة', 'اسم'), ('البيضاء', 'اسم'), ('نظراً', 'اسم'), ('بيئتها', 'اسم'), ('الهادئة٣', 'اسم'), ('اعتمدت', 'فعل'), ('المغرب', 'اسم'), ('العلم', 'اسم'), ('الوطنيّ', 'اسم'), ('رسمياً', 'اسم'), ('السابع', 'اسم'), ('شهر', 'اسم'), ('الثاني', 'اسم'), ('لعام', 'اسم'), ('م،', 'اسم'), ('رايةً', 'اسم'), ('باللون', 'اسم'), ('الأحمر', 'اسم'), ('فقط', 'اسم'), ('أيّة', None), ('علامات', 'اسم'), ('أخرى،', None), ('وصمّم', 'اسم'), ('العلم', 'اسم'), ('المغربيّ', 'اسم'), ('السلطان', 'اسم'), ('يوسف', 'اسم'), ('حكم', 'اسم'), ('البلاد', 'اسم'), ('عاميّ', 'اسم'), ('م،', 'اسم'), ('يتألّف', 'اسم'), ('العلم', 'اسم'), ('مستطيل', 'اسم'), ('باللون', 'اسم'), ('الأحمر', 'اسم'), ('تتوسطه', 'اسم'), ('نجمة', 'اسم'), ('خماسية', 'اسم'), ('باللون', 'اسم'), ('الأخضر،', 'اسم'), ('يرمز', 'اسم'), ('اللون', 'اسم'), ('الأحمر', 'اسم'), ('الشجاعة', 'اسم'), ('والقوة،', 'اسم'), ('يُشير', 'اسم'), ('اللون', 'اسم'), ('الأخضر', 'اسم'), ('الدين', 'اسم'), ('الإسلامي', 'اسم'), ('ويرمز', 'اسم'), ('للحب،', 'اسم'), ('والفرح،', 'اسم'), ('والأمل،', 'اسم'), ('والسلام،', 'اسم'), ('والحكمة،', 'اسم'), ('النجمة', 'اسم'), ('الخماسية', 'اسم'), ('فتُمثّل', 'اسم'), ('أركان', 'فعل'), ('الإسلام', 'اسم'), ('الخمسة٤', 'اسم'), ('يبلغ', 'اسم'), ('عدد', 'اسم'), ('سكان', 'اسم'), ('المغرب', 'اسم'), ('بحسب', 'اسم'), ('إحصائيات', 'فعل'), ('الأمم', 'اسم'), ('المتحدة', 'اسم'), ('حتّى', 'اسم'), ('اليوم', 'اسم'), ('الثاني', 'اسم'), ('شهر', 'اسم'), ('لعام', 'اسم'), ('نسمة،', 'اسم'), ('بمتوسط', 'اسم'), ('عمر', 'اسم'), ('عام،', 'اسم'), ('تصل', 'اسم'), ('الكثافة', 'اسم'), ('السكانية', 'اسم'), ('شخص', 'اسم'), ('لكلّ', 'اسم'), ('كيلو', 'اسم'), ('متر', 'اسم'), ('مربع،', 'اسم'), ('تحتل', 'اسم'), ('المغرب', 'اسم'), ('المرتبة', 'اسم'), ('عالمياً', 'اسم'), ('عدد', 'اسم'), ('السكان،', 'اسم'), ('ويُمثّل', 'اسم'), ('عددهم', 'اسم'), ('نسبةً', 'اسم'), ('تصل', 'اسم'), ('إجماليّ', None), ('سكان', 'اسم'), ('العالم،٥', 'اسم'), ('ويتألّف', 'اسم'), ('الشعب', 'اسم'), ('المغربيّ', 'اسم'), ('عدّة', 'اسم'), ('فئات', 'اسم'), ('عرقية', 'اسم'), ('مختلفة، ...

# %% [markdown]
# Machine Learning Approach :

# %% [markdown]
# the NLTK library provides both rule-based and machine learning-based approaches for natural language processing tasks. However, the part-of-speech tagging method we used with NLTK (nltk.pos_tag) utilizes a pre-trained statistical model based on a machine learning algorithm. This algorithm has been trained on annotated corpora to learn patterns in the data and predict part-of-speech tags for unseen text based on these learned patterns. Therefore, it falls under the category of machine learning-based approach.

# %%
nltk.download('averaged_perceptron_tagger')

# %%
# Perform part-of-speech tagging
tagged_tokens = nltk.pos_tag(stemmed_tokens)
print(tagged_tokens)
# Out:
# [('ثقف', 'JJ'), ('حول', 'NNP'), ('غرب', 'NNP'), ('تمت', 'NNP'), ('كتب', 'NNP'), ('بسط', 'NNP'), ('حمد', 'NNP'), ('مرو', 'NNP'), ('اخر', 'NNP'), ('حدث', 'NNP'), ('١٨٣١', 'CD'), ('،', 'VBD'), ('٣', 'CD'), ('٢٠٢١', 'CD'), ('تقع', 'NN'), ('غرب', 'NNP'), ('قرة', 'NNP'), ('ريقي،', 'NNP'), ('حدد', 'NNP'), ('وقع', 'NNP'), ('جغراف', 'NNP'), ('إحداث', 'NNP'), ('درج', 'NNP'), ('شمل', 'NNP'), ('درج', 'NNP'), ('غربا،', 'NNP'), ('ان', 'NNP'), ('سحل', 'NNP'), ('حيط', 'NNP'), ('طلس', 'NNP'), ('بحر', 'NNP'), ('ابض', 'NNP'), ('توسط', 'NNP'), ('فصل', 'NNP'), ('بين', 'NNP'), ('ضيق', 'NNP'), ('جبل', 'NNP'), ('طارق،', 'NNP'), ('تحد', 'NNP'), ('جنب', 'NNP'), ('شرق', 'NNP'), ('دول', 'NNP'), ('جزائر،', 'NNP'), ('جنب', 'NNP'), ('جنب', 'NNP'), ('جمهور', 'NNP'), ('موريتانية،', 'NNP'), ('يشر', 'NNP'), ('ان', 'NNP'), ('ساح', 'NNP'), ('غرب', 'NNP'), ('جمل', 'NNP'), ('بلغ', 'NNP'), ('حلي', 'NNP'), ('كم١٢', 'NNP'), ('تعد', 'NNP'), ('دين', 'NNP'), ('ربط', 'NNP'), ('عصم', 'NNP'), ('غرب،', 'NNP'), ('يقم', 'NNP'), ('حلي', 'NNP'), ('مة،', 'NNP'), ('وفق', 'NNP'), ('إحصائ', 'NNP'), ('شهر', 'NNP'), ('عام', 'NNP'), ('م،', 'NNP'), ('وزع', 'NNP'), ('ساح', 'NNP'), ('بلغ', 'NNP'), ('كم،', 'NNP'), ('بلغ', 'NNP'), ('كثف', 'NNP'), ('سكن', 'NNP'), ('شخص', 'NNP'), ('لكل', 'NNP'), ('كيلومتر', 'NNP'), ('ربع،', 'NNP'), ('طلق', 'NNP'), ('دين', 'NNP'), ('ربط', 'NNP'), ('عدة', 'NNP'), ('قب،', 'NNP'), ('شنط', 'NNP'), ('افريقيا؛', 'NNP'), ('لأن', 'NNP'), ('شرع', 'NNP'), ('وسع', 'NNP'), ('علم', 'NNP'), ('ثري', 'NNP'), ('مميزة،', 'NNP'), ('ضفة', 'NNP'), ('بني', 'NNP'), ('حكم', 'NNP'), ('نزل', 'NNP'), ('تم', 'NNP'), ('حول', 'NNP'), ('دق،', 'NNP'), ('سمى', 'NNP'), ('ايض', 'NNP'), ('بمد', 'NNP'), ('زهر', 'NNP'), ('حوئ', 'NNP'), ('حدق', 'NNP'), ('شسع', 'NNP'), ('جميلة،', 'NNP'), ('لقب', 'NNP'), ('ربط', 'NNP'), ('دين', 'NNP'), ('يضء', 'NNP'), ('نظر', 'NNP'), ('بيئ', 'NNP'), ('هادئة٣', 'NNP'), ('عمد', 'NNP'), ('غرب', 'NNP'), ('علم', 'NNP'), ('وطن', 'NNP'), ('رسم', 'NNP'), ('سبع', 'NNP'), ('شهر', 'NNP'), ('ثني', 'NNP'), ('لعم', 'NNP'), ('م،', 'NNP'), ('رية', 'NNP'), ('لون', 'NNP'), ('حمر', 'NNP'), ('فقط', 'NNP'), ('اية', 'NNP'), ('علم', 'NNP'), ('خرى،', 'NNP'), ('صمم', 'NNP'), ('علم', 'NNP'), ('غرب', 'NNP'), ('سلط', 'NNP'), ('وسف', 'NNP'), ('حكم', 'NNP'), ('بلد', 'NNP'), ('عمي', 'NNP'), ('م،', 'NNP'), ('ألف', 'NNP'), ('علم', 'NNP'), ('طيل', 'NNP'), ('لون', 'NNP'), ('حمر', 'NNP'), ('وسط', 'NNP'), ('نجم', 'NNP'), ('خمس', 'NNP'), ('لون', 'NNP'), ('خضر،', 'NNP'), ('رمز', 'NNP'), ('لون', 'NNP'), ('حمر', 'NNP'), ('شجع', 'NNP'), ('قوة،', 'NNP'), ('يشر', 'NNP'), ('لون', 'NNP'), ('خضر', 'NNP'), ('دين', 'NNP'), ('سلم', 'NNP'), ('رمز', 'NNP'), ('حب،', 'NNP'), ('رح،', 'NNP'), ('مل،', 'NNP'), ('لم،', 'NNP'), ('حكمة،', 'NNP'), ('نجم', 'NNP'), ('خمس', 'NNP'), ('مثل', 'NNP'), ('ارك', 'NNP'), ('سلم', 'NNP'), ('خمسة٤', 'NNP'), ('بلغ', 'NNP'), ('عدد', 'NNP'), ('سكن', 'NNP'), ('غرب', 'NNP'), ('حسب', 'NNP'), ('حصئ', 'NNP'), ('امم', 'NNP'), ('تحد', 'NNP'), ('حتى', 'NNP'), ('اليوم', 'NNP'), ('ثني', 'NNP'), ('شهر', 'NNP'), ('لعم', 'NNP'), ('مة،', 'NNP'), ('توسط', 'NNP'), ('عمر', 'NNP'), ('عم،', 'NNP'), ('تصل', 'NNP'), ('كثف', 'NNP'), ('سكن', 'NNP'), ('شخص', 'NNP'), ('لكل', 'NNP'), ('كيلو', 'NNP'), ('متر', 'NNP'), ('ربع،', 'NNP'), ('حتل', 'NNP'), ('غرب', 'NNP'), ('رتب', 'NNP'), ('علم', 'NNP'), ('عدد', 'NNP'), ('كن،', 'NNP'), ('مثل', 'NNP'), ('عدد', 'NNP'), ('نسب', 'NNP'), ('تصل', 'NNP'), ('جمل', 'NNP'), ('سكن', 'NNP'), ('عالم،٥', 'NNP'), ('ألف', 'NNP'), ('شعب', 'NNP'), ('غرب', 'NNP'), ('عدة', 'NNP'), ('فئت', 'NNP'), ('عرق', 'NNP'), ('مختلفة،', 'NNP'), ('اهم', 'NNP'), ('عرب', 'NNP'), ('ازغ', 'NNP'), ('وهم', 'NNP'), ('سكن', 'NNP'), ('صليون،', 'NNP'), ('أقل', 'NNP'), ('ورب', 'NNP'), ('عرف', 'NNP'), ('بسم', 'NNP'), ('غرب', 'NNP'), ('يض،', 'NNP'), ('وهم', 'NNP'), ('غرب', 'NNP'), ('اصل', 'NNP'), ('ورب', 'NNP'), ('اسب', 'NNP'), ('فرنسيين،', 'NNP'), ('ضفة', 'NNP'), ('جمع', 'NNP'), ('هود٦', 'NNP'), ('يعد', 'NNP'), ('نظم', 'NNP'), ('حكم', 'NNP'), ('دول', 'NNP'), ('غرب', 'NNP'), ('ملك', 'NNP'), ('دستور', 'NNP'), ('اقر', 'NNP'),  ...

# %% [markdown]
# with Farasa API :

# %%
# Define the URL of the Farasa POS tagging API
url = 'https://farasa.qcri.org/webapi/pos/'

# API key provided by Farasa
api_key = "wSBJontyOLZkxatynQ"

# Prepare the payload data
payload = {'text': ' '.join(filtered_arabic_tokens), 'api_key': api_key}

# Send a POST request to the Farasa POS tagging API
response = requests.post(url, data=payload)

# Parse the JSON response
result = json.loads(response.text)

# Extract the list of tokens
pos = result.get('text', [])

# Print the response
print(pos)
# Out:
# [{'surface': 'S', 'POS': 'S', 'num': '', 'position': 'B'}, {'surface': 'ثقاف +ة', 'POS': 'NOUN+NSUFF', 'num': 'FS', 'position': 'B'}, {'surface': 'عام +ة', 'POS': 'ADJ+NSUFF', 'num': 'FS', 'position': 'B'}, {'surface': 'حول', 'POS': 'V', 'num': '', 'position': 'B'}, {'surface': 'ال+ مغرب', 'POS': 'DET+NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'تم +ت', 'POS': 'V+PRON', 'num': '', 'position': 'B'}, {'surface': 'ال+ كتاب +ة', 'POS': 'DET+NOUN+NSUFF', 'num': 'FS', 'position': 'B'}, {'surface': 'ب+', 'POS': 'PREP', 'num': '', 'position': 'B'}, {'surface': 'واسط +ة', 'POS': 'NOUN+NSUFF', 'num': 'FS', 'position': 'I'}, {'surface': 'محمد', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'مروان', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'آخر', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'تحديث', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '١٨٣١', 'POS': 'NUM', 'num': 'MP', 'position': 'B'}, {'surface': '،', 'POS': 'PUNC', 'num': '', 'position': 'B'}, {'surface': '٣', 'POS': 'NUM', 'num': 'MP', 'position': 'B'}, {'surface': 'فبراير', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '٢٠٢١', 'POS': 'NUM', 'num': 'MP', 'position': 'B'}, {'surface': 'تقع', 'POS': 'V', 'num': '', 'position': 'B'}, {'surface': 'ال+ مغرب', 'POS': 'DET+NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'في', 'POS': 'PREP', 'num': '', 'position': 'B'}, {'surface': 'شمال', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'قار +ة', 'POS': 'NOUN+NSUFF', 'num': 'FS', 'position': 'B'}, {'surface': 'أفريقي', 'POS': 'ADJ', 'num': 'MS', 'position': 'B'}, {'surface': '،', 'POS': 'PUNC', 'num': '', 'position': 'B'}, {'surface': 'و+', 'POS': 'CONJ', 'num': '', 'position': 'B'}, {'surface': 'يتحدد', 'POS': 'V', 'num': '', 'position': 'I'}, {'surface': 'موقع', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '+ها', 'POS': 'PRON', 'num': '', 'position': 'I'}, {'surface': 'جغرافيا', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'ب+', 'POS': 'PREP', 'num': '', 'position': 'B'}, {'surface': 'إحداثي +ات', 'POS': 'NOUN+NSUFF', 'num': 'FP', 'position': 'I'}, {'surface': 'درج +ة', 'POS': 'NOUN+NSUFF', 'num': 'FS', 'position': 'B'}, {'surface': 'شمال', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '+ا', 'POS': 'CASE', 'num': '', 'position': 'I'}, {'surface': 'و', 'POS': 'CONJ', 'num': '', 'position': 'B'}, {'surface': 'درج +ات', 'POS': 'NOUN+NSUFF', 'num': 'FP', 'position': 'B'}, {'surface': 'غرب', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '+ا', 'POS': 'CASE', 'num': '', 'position': 'I'}, {'surface': '،', 'POS': 'PUNC', 'num': '', 'position': 'B'}, {'surface': 'إذ', 'POS': 'PART', 'num': '', 'position': 'B'}, {'surface': 'إن', 'POS': 'PART', 'num': '', 'position': 'B'}, {'surface': 'ل+', 'POS': 'PREP', 'num': '', 'position': 'B'}, {'surface': '+ها', 'POS': 'PRON', 'num': '', 'position': 'I'}, {'surface': 'سواحل', 'POS': 'NOUN', 'num': 'FP', 'position': 'B'}, {'surface': 'على', 'POS': 'PREP', 'num': '', 'position': 'B'}, {'surface': 'ال+ محيط', 'POS': 'DET+NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'ال+ أطلسي', 'POS': 'DET+ADJ', 'num': 'MS', 'position': 'B'}, {'surface': 'و+', 'POS': 'CONJ', 'num': '', 'position': 'B'}, {'surface': 'ال+ بحر', 'POS': 'DET+NOUN', 'num': 'MS', 'position': 'I'}, {'surface': 'ال+ أبيض', 'POS': 'DET+ADJ', 'num': 'MS', 'position': 'B'}, {'surface': 'ال+ متوسط', 'POS': 'DET+ADJ', 'num': 'MS', 'position': 'B'}, {'surface': 'الذي', 'POS': 'PART', 'num': '', 'position': 'B'}, {'surface': 'يفصل', 'POS': 'V', 'num': '', 'position': 'B'}, {'surface': 'بين', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '+هما', 'POS': 'PRON', 'num': '', 'position': 'I'}, {'surface': 'مضيق', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'جبل', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'طارق', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '،', 'POS': 'PUNC', 'num': '', 'position': 'B'}, {'surface': ' ...

# %% [markdown]
# ---
#
#
# ## Named Entity Recognition (NER)

# %% [markdown]
# with NLTK :

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')

# %%
named_entities = ne_chunk(tagged_tokens)
print(named_entities)
# Out:
# (S
#   ثقف/JJ
#   (ORGANIZATION حول/NNP)
#   غرب/NNP
#   تمت/NNP
#   كتب/NNP
#   بسط/NNP
#   حمد/NNP
#   مرو/NNP
#   اخر/NNP
#   حدث/NNP
#   ١٨٣١/CD
#   ،/VBD
#   ٣/CD
#   ٢٠٢١/CD
#   (ORGANIZATION تقع/NN)
#   (ORGANIZATION غرب/NNP)
#   قرة/NNP
#   ريقي،/NNP
#   حدد/NNP
#   وقع/NNP
#   جغراف/NNP
#   إحداث/NNP
#   درج/NNP
#   شمل/NNP
#   درج/NNP
#   غربا،/NNP
#   ان/NNP
#   سحل/NNP
#   حيط/NNP
#   طلس/NNP
#   بحر/NNP
#   ابض/NNP
#   توسط/NNP
#   فصل/NNP
#   بين/NNP
#   ضيق/NNP
#   جبل/NNP
#   طارق،/NNP
#   تحد/NNP
#   جنب/NNP
#   شرق/NNP
#   دول/NNP
#   جزائر،/NNP
#   جنب/NNP
#   جنب/NNP
#   جمهور/NNP
#   موريتانية،/NNP
#   يشر/NNP
#   ان/NNP
#   ساح/NNP
#   غرب/NNP
#   جمل/NNP
#   بلغ/NNP
#   حلي/NNP
#   كم١٢/NNP
#   تعد/NNP
#   دين/NNP
#   ربط/NNP
#   عصم/NNP
#   غرب،/NNP
#   يقم/NNP
#   حلي/NNP
#   مة،/NNP
#   وفق/NNP
#   إحصائ/NNP
#   شهر/NNP
#   عام/NNP
#   م،/NNP
#   وزع/NNP
#   ساح/NNP
#   بلغ/NNP
#   كم،/NNP
#   بلغ/NNP
#   كثف/NNP
#   سكن/NNP
#   شخص/NNP
#   لكل/NNP
#   كيلومتر/NNP
#   ربع،/NNP
#   طلق/NNP
#   دين/NNP
#   ربط/NNP
#   عدة/NNP
#   قب،/NNP
#   شنط/NNP
#   افريقيا؛/NNP
#   لأن/NNP
#   شرع/NNP
#   وسع/NNP
#   علم/NNP
#   ثري/NNP
#   مميزة،/NNP
#   ضفة/NNP
#   بني/NNP
#   حكم/NNP
#   نزل/NNP
#   تم/NNP
#   حول/NNP
#   دق،/NNP
#   سمى/NNP
#   ايض/NNP
#   بمد/NNP
#   زهر/NNP
#   حوئ/NNP
#   حدق/NNP
#   شسع/NNP
#   جميلة،/NNP
#   لقب/NNP
#   ربط/NNP
#   دين/NNP
#   يضء/NNP
#   نظر/NNP
#   بيئ/NNP
#   هادئة٣/NNP
#   عمد/NNP
#   غرب/NNP
#   علم/NNP
#   وطن/NNP
#   رسم/NNP
#   سبع/NNP
#   شهر/NNP
#   ثني/NNP
#   لعم/NNP
#   م،/NNP
#   رية/NNP
#   لون/NNP
#   حمر/NNP
#   فقط/NNP
#   اية/NNP
#   علم/NNP
#   خرى،/NNP
#   صمم/NNP
#   علم/NNP
#   غرب/NNP
#   سلط/NNP
#   وسف/NNP
#   حكم/NNP
#   بلد/NNP
#   عمي/NNP
#   م،/NNP
#   ألف/NNP
#   علم/NNP
#   طيل/NNP
#   لون/NNP
#   حمر/NNP
#   وسط/NNP
#   نجم/NNP
#   خمس/NNP
#   لون/NNP
#   خضر،/NNP
#   رمز/NNP
#   لون/NNP
#   حمر/NNP
#   شجع/NNP
#   قوة،/NNP
#   يشر/NNP
#   لون/NNP
#   خضر/NNP
#   دين/NNP
#   سلم/NNP
#   رمز/NNP
#   حب،/NNP
#   رح،/NNP
#   مل،/NNP
#   لم،/NNP
#   حكمة،/NNP
#   نجم/NNP
#   خمس/NNP
#   مثل/NNP
#   ارك/NNP
#   سلم/NNP
#   خمسة٤/NNP
#   بلغ/NNP
#   عدد/NNP
#   سكن/NNP
#   غرب/NNP
#   حسب/NNP
#   حصئ/NNP
#   امم/NNP
#   تحد/NNP
#   حتى/NNP
#   اليوم/NNP
#   ثني/NNP
#   شهر/NNP
#   لعم/NNP
#   مة،/NNP
#   توسط/NNP
#   عمر/NNP
#   عم،/NNP
#   تصل/NNP
#   كثف/NNP
#   سكن/NNP
#   شخص/NNP
#   لكل/NNP
#   كيلو/NNP
#   متر/NNP
#   ربع،/NNP
#   حتل/NNP
#   غرب/NNP
#   رتب/NNP
#   علم/NNP
#   عدد/NNP
#   كن،/NNP
#   مثل/NNP
#   عدد/NNP
#   نسب/NNP
#   تصل/NNP
#   جمل/NNP
#   سكن/NNP
#   عالم،٥/NNP
#   ألف/NNP
#   شعب/NNP
#   غرب/NNP
#   عدة/NNP
#   فئت/NNP
#   عرق/NNP
#   مختلفة،/NNP
#   اهم/NNP
#   عرب/NNP
#   ازغ/NNP
#   وهم/NNP
#   سكن/NNP
#   صليون،/NNP
#   أقل/NNP
#   ورب/NNP
#   عرف/NNP
#   بسم/NNP
#   غرب/NNP
#   يض،/NNP
#   وهم/NNP
#   غرب/NNP
#   اصل/NNP
#   ورب/NNP
#   اسب/NNP
#   فرنسيين،/NNP
#   ضفة/NNP
#   جمع/NNP
#   هود٦/NNP
#   يعد/NNP
#   نظم/NNP
#   حكم/NNP
#   دول/NNP
#   غرب/NNP
#   ملك/NNP
#   دستور/NNP
#   اقر/NNP
#   دستور/NNP
#   اول/NNP
#   عام/NNP
#   م،/NNP
#   نظم/NNP
#   رلم/NNP
#   ديمقراطي/NNP
#   اجتماعي،/NNP
#   عبر/NNP
#   ملك/NNP
#   صحب/NNP
#   سلط/NNP
#   علا/NNP
#   دولة،/NNP
#   قئد/NNP
#   على/NNP
#   قوت/NNP
#   سلح/NNP
#   ملكية،/NNP
#   رأس/NNP
#   جلس/NNP
#   على/NNP
#   قضء،/NNP
#   متل/NNP
#   عدة/NNP
#   صلح/NNP
#   نه؛/NNP
#   تعي/NNP
#   رئس/NNP
#   زرء/NNP
#   جرء/NNP
#   نخب/NNP
#   تشريعية،/NNP
#   إقل/NNP
#   زرء،/NNP
#   وحل/NNP
#   جلس/NNP
#   نوب/NNP
#   حكومة،/NNP
#   ألف/NNP
#   رلم/NNP
#   غرب/NNP
#   جلس/NNP
#   تشريعيين،/NNP
#   جلس/NNP
#   نوب/NNP
#   يضم/NNP
#   عضا/NNP
#   يتم/NNP
#   نخب/NNP
#   لمد/NNP
#   عم،/NNP
#   جلس/NNP
#   شار/NNP
#   يحي/NNP
#   عضا/NNP
#   اقل/NNP
#   عضا/NNP
#   كثر،/NNP
#   يتم/NNP
#   نخب/NNP
#   شكل/NNP
#   بشر/NNP
#   لمد/NNP
#   نت٧/NNP
#   تمز/NNP
#   غرب/NNP
#   جمع/NNP
#   قطع/NNP
#   صنع/NNP
#   تنع/NNP
#   دور/NNP
#   برز/NNP
#   قلل/NNP
#   طالة،/NNP
#   نظر/NNP
#   خصب/NNP
#   اراضيها؛/NNP
#   قطع/NNP
#   زرع/NNP
#   يهم/NNP
#   قتصاد،/NNP
#   ويس/NNP
#   نسب/NNP
#   تصل/NNP
#   نتج/NNP
#   حلي/NNP
#   جمل/NNP
#   شغل/NNP
#   حلي/NNP
#   ايد/NNP
#   عاملة،/NNP
#   سبب/NNP
#   أثر/NNP
#   كبر/NNP
#   نمو/NNP
#   قصد/NNP
#   فقد/NNP
#   اول/NNP
#   حكم/NNP
#   غرب/NNP
#   هما/NNP
#   بلغ/NNP
#   طرق/NNP
#   خطط/NNP
#   غرب/NNP
#   خضر/NNP
#   صندوق/NNP
#   نمي/NNP
#   حية٨/NNP
#   يعد/NNP
#   وسف/NNP
#   ايض/NNP
#   صدر/NNP
#   ثرة/NNP
#   غرب/NNP
#   قلة/NNP
#   ورد/NNP
#   معدنية،/NNP
#   يسا/NNP
#   قطع/NNP
#   صنع/NNP
#   نسب/NNP
#   تصل/NNP
#   نتج/NNP
#   حلي/NNP
#   جمل/NNP
#   وظف/NNP
#   قوى/NNP
#   عاملة،/NNP
#   قطع/NNP
#   صنع/NNP
#   رئيسية؛/NNP
#   منسوجات،/NNP
#   سلع/NNP
#   جلدية،/NNP
#   جهز/NNP
#   غذية،/NNP
#   كرر/NNP
#   فط،/NNP
#   بين/NNP
#   شهد/NNP
#   قطع/NNP
#   جدد/NNP
#   زدهار/NNP
#   ضح؛/NNP
#   كيمياء،/NNP
#   رت،/NNP
#   الكترونيات،/NNP
#   قطع/NNP
#   طيران،/NNP
#   قطع/NNP
#   خدم/NNP
#   مثل/NNP
#   نصف/NNP
#   نتج/NNP
#   حلي/NNP
#   جمل/NNP
#   وفر/NNP
#   فرص/NNP
#   عمل/NNP
#   نسب/NNP
#   ايد/NNP
#   عاملة٨/NNP
#   تمز/NNP
#   غرب/NNP
#   طبع/NNP
#   خلب/NNP
#   ريدة،/NNP
#   انه/NNP
#   تحي/NNP
#   غابات،/NNP
#   هول،/NNP
#   ين،/NNP
#   قمم/NNP
#   جبل/NNP
#   طلس،/NNP
#   صخر/NNP
#   صحر/NNP
#   رمل/NNP
#   جنوب،/NNP
#   ضفة/NNP
#   وقع/NNP
#   دين/NNP
#   خلف/NNP
#   يمكن/NNP
#   زيارتها،/NNP
#   ان/NNP
#   غرب/NNP
#   تعد/NNP
#   دول/NNP
#   نشر/NNP
#   سمح/NNP
#   عيش/NNP
#   دين،/NNP
#   نتج/NNP
#   لذلك/NNP
#   عدد/NNP
#   شكل/NNP
#   سيح/NNP
#   غرب/NNP
#   وع،/NNP
#   ملك/NNP
#   غرب/NNP
#   عدد/NNP
#   وقع/NNP
#   ارخ/NNP
#   ثري/NNP
#   درج/NNP
#   قئم/NNP
#   سكو/NNP
#   رث،/NNP
#   ومن/NNP
#   أي٩/NNP
#   تمز/NNP
#   عظم/NNP
#   نطق/NNP
#   وقع/NNP
#   صحراء/NNP
#   غرب/NNP
#   ناخ/NNP
#   حار/NNP
#   صيف/NNP
#   عدل/NNP
#   شتء،/NNP
#   سمر/NNP
#   وسم/NNP
#   مطر/NNP
#   شهر/NNP
#   اول/NNP
#   حتى/NNP
#   شهر/NNP
#   سن،/NNP
#   ركز/NNP
#   هطل/NNP
#   مطر/NNP
#   لد،/NNP
#   خفض/NNP
#   درج/NNP
#   حتى/NNP
#   جنوب،/NNP
#   يؤد/NNP
#   تير/NNP
#   كنر/NNP
#   يمر/NNP
#   قبل/NNP
#   شطئ/NNP
#   غرب/NNP
#   قرر/NNP
#   حلة/NNP
#   جوية٢١٠/NNP
#   عبر/NNP
#   غرب/NNP
#   موط/NNP
#   ازغ/NNP
#   قرب/NNP
#   عام/NNP
#   ميلاد،/NNP
#   وفي/NNP
#   عام/NNP
#   ضمت/NNP
#   روم/NNP
#   موريتانيا،/NNP
#   أصبح/NNP
#   جزء/NNP
#   جاح/NNP
#   دل،/NNP
#   عام/NNP
#   يطر/NNP
#   عليها/NNP
#   عرب،/NNP
#   بعد/NNP
#   يطر/NNP
#   عليها/NNP
#   كل/NNP
#   سبن/NNP
#   رتغال/NNP
#   وحد/NNP
#   قبل/NNP
#   دفع/NNP
#   اراضيها،/NNP
#   وفي/NNP
#   عام/NNP
#   غرب/NNP
#   حكم/NNP
#   علويين١١/NNP
#   تم/NNP
#   رسل/NNP
#   جح،/NNP
#   شكر/NNP
#   حقق/NNP
#   حفظ/NNP
#   وضع/NNP
#   حقق/NNP
#   حفظ/NNP
#   وضع/NN)

# %% [markdown]
# with Farasa API : Named entity recognition (NER) is the task of tagging entities in text with their corresponding type. Approaches typically use BIO notation, which differentiates the beginning (B) and the inside (I) of entities. O is used for non-entity tokens.

# %%
# Define the URL of the Farasa NER tagging API
url = 'https://farasa.qcri.org/webapi/ner/'

# API key provided by Farasa
api_key = "wSBJontyOLZkxatynQ"

# Prepare the payload data
payload = {'text': cleaned_text, 'api_key': api_key}

# Send a POST request to the Farasa NER tagging API
data = requests.post(url, data=payload)

# Parse the JSON response
result = json.loads(data.text)

# Extract the list of tokens
pos = result.get('text', [])

# Print the response
print(pos)
# Out:
# ['ثقافة/O', 'عامة/O', 'حول/O', 'المغرب/B-LOC', 'تمت/O', 'الكتابة/O', 'بواسطة/O', 'محمد/B-PERS', 'مروان/I-PERS', 'آخر/O', 'تحديث/O', '١٨٣١/O', '،/O', '٣/O', 'فبراير/O', '٢٠٢١/O', 'تقع/O', 'المغرب/B-LOC', 'في/O', 'شمال/O', 'قارة/O', 'أفريقي/O', '،/O', 'ويتحدد/O', 'موقعها/O', 'جغرافيا/O', 'بإحداثيات/O', 'درجة/O', 'شمالا/O', 'و/O', 'درجات/O', 'غربا/O', '،/O', 'إذ/O', 'إن/O', 'لها/O', 'سواحل/O', 'على/O', 'المحيط/B-LOC', 'الأطلسي/I-LOC', 'والبحر/B-LOC', 'الأبيض/I-LOC', 'المتوسط/I-LOC', 'الذي/O', 'يفصل/O', 'بينهما/O', 'مضيق/O', 'جبل/B-PERS', 'طارق/I-PERS', '،/O', 'كما/O', 'تحدها/O', 'من/O', 'الجانب/O', 'الشرقي/O', 'دولة/O', 'الجزائر/B-LOC', '،/O', 'ومن/O', 'الجانب/O', 'الجنوبي/O', 'الجمهورية/O', 'الموريتانية/O', '،/O', 'ويشار/O', 'إلى/O', 'أن/O', 'مساحة/O', 'المغرب/B-LOC', 'الإجمالية/O', 'تبلغ/O', 'حوالي/O', 'كم١٢/O', 'تعد/O', 'مدينة/O', 'الرباط/B-LOC', 'عاصمة/O', 'المغرب/B-LOC', '،/O', 'ويقيم/O', 'فيها/O', 'حوالي/O', 'نسمة/O', '،/O', 'وفقا/O', 'لإحصائيات/O', 'شهر/O', 'تموز/O', 'من/O', 'عام/O', 'م/O', '،/O', 'حيث/O', 'يتوزعون/O', 'على/O', 'مساحة/O', 'تبلغ/O', 'كم/O', '،/O', 'إذ/O', 'تبلغ/O', 'الكثافة/O', 'السكانية/O', 'فيها/O', 'نحو/O', 'شخص/O', 'لكل/O', 'كيلومتر/O', 'مربع/O', '،/O', 'ويطلق/O', 'على/O', 'مدينة/O', 'الرباط/O', 'عدة/O', 'ألقاب/O', '،/O', 'مثل/O', 'واشنطن/B-LOC', 'شمال/O', 'أفريقيا/B-LOC', '؛/O', 'لأن/O', 'شوارعها/O', 'واسعة/O', 'ومعالمها/O', 'الأثرية/O', 'مميزة/O', '،/O', 'بالإضافة/O', 'إلى/O', 'مبانيها/O', 'الحكومية/O', 'والمنازل/O', 'التي/O', 'تم/O', 'تحويلها/O', 'إلى/O', 'فنادق/O', '،/O', 'وتسمى/O', 'أيضا/O', 'بمدينة/O', 'الزهور/O', 'لاحتوائها/O', 'على/O', 'حدائق/O', 'شاسعة/O', 'وجميلة/O', '،/O', 'كما/O', 'تلقب/O', 'الرباط/B-LOC', 'بالمدينة/B-LOC', 'البيضاء/O', 'نظرا/O', 'إلى/O', 'بيئتها/O', 'الهادئة٣/O', 'اعتمدت/O', 'المغرب/B-LOC', 'العلم/O', 'الوطني/O', 'رسميا/O', 'في/O', 'السابع/O', 'عشر/O', 'من/O', 'شهر/O', 'تشرين/O', 'الثاني/O', 'لعام/O', 'م/O', '،/O', 'حيث/O', 'كان/O', 'قبل/O', 'ذلك/O', 'راية/O', 'باللون/O', 'الأحمر/O', 'فقط/O', 'دون/O', 'أية/O', 'علامات/O', 'أخرى/O', '،/O', 'وصمم/O', 'العلم/O', 'المغربي/O', 'السلطان/O', 'يوسف/B-PERS', 'الذي/O', 'حكم/O', 'البلاد/O', 'بين/O', 'عامي/O', 'م/O', '،/O', 'حيث/O', 'يتألف/O', 'العلم/O', 'من/O', 'مستطيل/O', 'باللون/O', 'الأحمر/O', 'تتوسطه/O', 'نجمة/O', 'خماسية/O', 'باللون/O', 'الأخضر/O', '،/O', 'إذ/O', 'يرمز/O', 'اللون/O', 'الأحمر/O', 'إلى/O', 'الشجاعة/O', 'والقوة/O', '،/O', 'فيما/O', 'يشير/O', 'اللون/O', 'الأخضر/O', 'إلى/O', 'الدين/O', 'الإسلامي/O', 'ويرمز/O', 'للحب/O', '،/O', 'والفرح/O', '،/O', 'والأمل/O', '،/O', 'والسلام/O', '،/O', 'والحكمة/O', '،/O', 'أما/O', 'النجمة/O', 'الخماسية/O', 'فتمثل/O', 'أركان/O', 'الإسلام/O', 'الخمسة٤/O', 'يبلغ/O', 'عدد/O', 'سكان/O', 'المغرب/B-LOC', 'بحسب/O', 'إحصائيات/O', 'الأمم/B-ORG', 'المتحدة/I-ORG', 'حتى/O', 'اليوم/O', 'الثاني/O', 'من/O', 'شهر/O', 'شباط/O', 'لعام/O', 'نحو/O', 'نسمة/O', '،/O', 'بمتوسط/O', 'عمر/O', 'عام/O', '،/O', 'في/O', 'حين/O', 'تصل/O', 'الكثافة/O', 'السكانية/O', 'فيها/O', 'إلى/O', 'شخص/O', 'لكل/O', 'كيلو/O', 'متر/O', 'مربع/O', '،/O', 'حيث/O', 'تحتل/O', 'المغرب/B-LOC', 'المرتبة/O', 'عالميا/O', 'من/O', 'حيث/O', 'عدد/O', 'السكان/O', '،/O', 'ويمثل/O', 'عددهم/O', 'نسبة/O', 'تصل/O', 'إلى/O', 'من/O', 'إجمالي/O', 'سكان/O', 'العالم/O', '،/O', '٥/O', 'ويتألف/O', 'الشعب/O', 'المغربي/O', 'من/O', 'عدة/O', 'فئات/O', 'عرقية/O', 'مختلفة/O', '،/O', 'أهمها/O', 'العرب/O', 'والأمازيغ/O', 'وهم/O', 'السكان/O', 'الأصليون/O', '،/O', 'وأقليات/O', 'من/O', 'الأوروبيين/O', 'المعروفين/O', 'باسم/O', 'المغاربة/O', 'البيض/O', '،/O', 'وهم/O', 'مغاربة/O', 'من/O', 'أصل/O', 'أوروبي/O', 'كالإسبان/O', 'والفرنسيين/O', '،/O', 'بالإضافة/O', 'إلى/O', 'مجموعة/O', 'من/O', 'اليهود٦/O', 'يعد/O', 'نظام/O', 'الحكم/O', 'في/O', 'دولة/O', 'المغرب/B-LOC', 'ملكيا/O', 'دستوريا/O', 'كما/O', 'أقره/O', 'الدستور/O', 'الأول/O', 'في/O', 'عام/O', 'م/O', '،/O', 'وهو/O', 'نظام/O', 'برلماني/O', 'ديمقراطي/O', 'اجتماعي/O', '،/O', 'يعتبر/O', 'فيه/O', 'الملك/O', 'صاحب/O', 'السلطة/O', 'العليا/O', 'في/O', 'الدولة/O', '،/O', 'والقائد/O', 'الأعلى/O', 'للقوات/O', 'المسلحة/O', 'الملكية/O ...

# %% [markdown]
# # **Synthesis**

# %% [markdown]
# Throughout the lab, I gained valuable insights into the intricacies of web scraping, data preprocessing, and natural language processing (NLP) techniques.
#
# Firstly, I learned how to utilize Beautiful Soup to extract data from web sources, enabling me to gather valuable information from diverse Arabic websites efficiently.
#
# Secondly, I delved into storing the scraped data in a NoSQL database like MongoDB, both locally and on MongoDB Atlas (Cloud). This hands-on experience familiarized me with new type of databases.
#
# Moving on to NLP, I grasped the significance of text cleaning, tokenization, and normalization in preparing textual data for analysis. Techniques such as removing stop words, punctuation, and special characters helped streamline the data and improve the quality of subsequent analyses.
#
# Exploring stemming and lemmatization provided valuable insights into different approaches to word normalization. While stemming offered a fast and lightweight method, lemmatization preserved the semantic meaning of words, albeit at a slightly higher computational cost.
#
# Additionally, I explored parts-of-speech (POS) tagging using both rule-based and machine learning approaches. While rule-based tagging allowed for explicit rule definitions, machine learning-based tagging leveraged annotated data to identify patterns and nuances in language usage.
#
# Furthermore, I experimented with named entity recognition (NER) using NLTK and the Farasa API, which played a crucial role in identifying and categorizing entities such as names, organizations, and locations in Arabic text. This experience broadened my understanding of utilizing REST APIs for NLP tasks.
#
# Overall, this lab equipped me with a comprehensive understanding of the data acquisition, preprocessing, and NLP pipeline, laying a solid foundation for future endeavors in data science and text analysis.
